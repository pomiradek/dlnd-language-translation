# %% [markdown]
# # Language Translation
# In this project, you’re going to take a peek into the realm of neural network machine translation.  You’ll be training a sequence to sequence model on a dataset of English and French sentences that can translate new sentences from English to French.
# ## Get the Data
# Since translating the whole language of English to French will take lots of time to train, we have provided you with a small portion of the English corpus.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import helper
import problem_unittests as tests

source_path = 'data/small_vocab_en'
target_path = 'data/small_vocab_fr'
source_text = helper.load_data(source_path)
target_text = helper.load_data(target_path)

# %% [markdown]
# ## Explore the Data
# Play around with view_sentence_range to view different parts of the data.

# %%
view_sentence_range = (0, 10)

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np

print('Dataset Stats')
print('Roughly the number of unique words: {}'.format(len({word: None for word in source_text.split()})))

sentences = source_text.split('\n')
word_counts = [len(sentence.split()) for sentence in sentences]
print('Number of sentences: {}'.format(len(sentences)))
print('Average number of words in a sentence: {}'.format(np.average(word_counts)))

print()
print('English sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(source_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
print()
print('French sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(target_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
# Out:
# Dataset Stats
# Roughly the number of unique words: 227
# Number of sentences: 137861
# Average number of words in a sentence: 13.225277634719028
#
# English sentences 0 to 10:
# new jersey is sometimes quiet during autumn , and it is snowy in april .
# the united states is usually chilly during july , and it is usually freezing in november .
# california is usually quiet during march , and it is usually hot in june .
# the united states is sometimes mild during june , and it is cold in september .
# your least liked fruit is the grape , but my least liked is the apple .
# his favorite fruit is the orange , but my favorite is the grape .
# paris is relaxing during december , but it is usually chilly in july .
# new jersey is busy during spring , and it is never hot in march .
# our least liked fruit is the lemon , but my least liked is the grape .
# the united states is sometimes busy during january , and it is sometimes warm in november .
#
# French sentences 0 to 10:
# new jersey est parfois calme pendant l' automne , et il est neigeux en avril .
# les états-unis est généralement froid en juillet , et il gèle habituellement en novembre .
# california est généralement calme en mars , et il est généralement chaud en juin .
# les états-unis est parfois légère en juin , et il fait froid en septembre .
# votre moins aimé fruit est le raisin , mais mon moins aimé est la pomme .
# son fruit préféré est l'orange , mais mon préféré est le raisin .
# paris est relaxant en décembre , mais il est généralement froid en juillet .
# new jersey est occupé au printemps , et il est jamais chaude en mars .
# notre fruit est moins aimé le citron , mais mon moins aimé est le raisin .
# les états-unis est parfois occupé en janvier , et il est parfois chaud en novembre .

# %% [markdown]
# ## Implement Preprocessing Function
# ### Text to Word Ids
# As you did with other RNNs, you must turn the text into a number so the computer can understand it. In the function `text_to_ids()`, you'll turn `source_text` and `target_text` from words to ids.  However, you need to add the `<EOS>` word id at the end of `target_text`.  This will help the neural network predict when the sentence should end.
#
# You can get the `<EOS>` word id by doing:
# ```python
# target_vocab_to_int['<EOS>']
# ```
# You can get other word ids using `source_vocab_to_int` and `target_vocab_to_int`.

# %%
def text_to_ids(source_text, target_text, source_vocab_to_int, target_vocab_to_int):
    """
    Convert source and target text to proper word ids
    :param source_text: String that contains all the source text.
    :param target_text: String that contains all the target text.
    :param source_vocab_to_int: Dictionary to go from the source words to an id
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :return: A tuple of lists (source_id_text, target_id_text)
    """
    # TODO: Implement Function
    source_id_text = [[source_vocab_to_int[word] for word in line.split(' ')] for line in source_text.split('\n')]
    target_id_text = [[target_vocab_to_int[word] for word in line.split(' ')] + [target_vocab_to_int['<EOS>']] for line in target_text.split('\n')] 

    
    return (source_id_text, target_id_text)

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_text_to_ids(text_to_ids)
# Out:
# Tests Passed

# %% [markdown]
# ### Preprocess all the data and save it
# Running the code cell below will preprocess all the data and save it to file.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
helper.preprocess_and_save_data(source_path, target_path, text_to_ids)

# %% [markdown]
# # Check Point
# This is your first checkpoint. If you ever decide to come back to this notebook or have to restart the notebook, you can start from here. The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np
import helper
import problem_unittests as tests

(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = helper.load_preprocess()

# %% [markdown]
# ### Check the Version of TensorFlow and Access to GPU
# This will check to make sure you have the correct version of TensorFlow and access to a GPU

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
from distutils.version import LooseVersion
import warnings
import tensorflow as tf
from tensorflow.python.layers.core import Dense

# Check TensorFlow Version
assert LooseVersion(tf.__version__) >= LooseVersion('1.1'), 'Please use TensorFlow version 1.1 or newer'
print('TensorFlow Version: {}'.format(tf.__version__))

# Check for a GPU
if not tf.test.gpu_device_name():
    warnings.warn('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# Out:
# TensorFlow Version: 1.1.0
# Default GPU Device: /gpu:0

# %% [markdown]
# ## Build the Neural Network
# You'll build the components necessary to build a Sequence-to-Sequence model by implementing the following functions below:
# - `model_inputs`
# - `process_decoder_input`
# - `encoding_layer`
# - `decoding_layer_train`
# - `decoding_layer_infer`
# - `decoding_layer`
# - `seq2seq_model`
#
# ### Input
# Implement the `model_inputs()` function to create TF Placeholders for the Neural Network. It should create the following placeholders:
#
# - Input text placeholder named "input" using the TF Placeholder name parameter with rank 2.
# - Targets placeholder with rank 2.
# - Learning rate placeholder with rank 0.
# - Keep probability placeholder named "keep_prob" using the TF Placeholder name parameter with rank 0.
# - Target sequence length placeholder named "target_sequence_length" with rank 1
# - Max target sequence length tensor named "max_target_len" getting its value from applying tf.reduce_max on the target_sequence_length placeholder. Rank 0.
# - Source sequence length placeholder named "source_sequence_length" with rank 1
#
# Return the placeholders in the following the tuple (input, targets, learning rate, keep probability, target sequence length, max target sequence length, source sequence length)

# %%
def model_inputs():
    """
    Create TF Placeholders for input, targets, learning rate, and lengths of source and target sequences.
    :return: Tuple (input, targets, learning rate, keep probability, target sequence length,
    max target sequence length, source sequence length)
    """
    # TODO: Implement Function
    input = tf.placeholder(tf.int32, [None, None], name='input')
    targets = tf.placeholder(tf.int32, [None, None], name='targets')
    lr = tf.placeholder(tf.float32, name='learning_rate')
    keep_prob = tf.placeholder(tf.float32, name='keep_prob')

    target_sequence_length = tf.placeholder(tf.int32, (None,), name='target_sequence_length')
    max_target_sequence_length = tf.reduce_max(target_sequence_length, name='max_target_len')
    source_sequence_length = tf.placeholder(tf.int32, (None,), name='source_sequence_length')
    return (input, targets, lr, keep_prob, target_sequence_length, max_target_sequence_length, source_sequence_length)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_inputs(model_inputs)
# Out:
# Tests Passed

# %% [markdown]
# ### Process Decoder Input
# Implement `process_decoder_input` by removing the last word id from each batch in `target_data` and concat the GO ID to the begining of each batch.

# %%
def process_decoder_input(target_data, target_vocab_to_int, batch_size):
    """
    Preprocess target data for encoding
    :param target_data: Target Placehoder
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :param batch_size: Batch Size
    :return: Preprocessed target data
    """
    # TODO: Implement Function
    ending = tf.strided_slice(target_data, [0, 0], [batch_size, -1], [1, 1])
    dec_input = tf.concat([tf.fill([batch_size, 1], target_vocab_to_int['<GO>']), ending], 1)
    return dec_input

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_process_encoding_input(process_decoder_input)
# Out:
# Tests Passed

# %% [markdown]
# ### Encoding
# Implement `encoding_layer()` to create a Encoder RNN layer:
#  * Embed the encoder input using [`tf.contrib.layers.embed_sequence`](https://www.tensorflow.org/api_docs/python/tf/contrib/layers/embed_sequence)
#  * Construct a [stacked](https://github.com/tensorflow/tensorflow/blob/6947f65a374ebf29e74bb71e36fd82760056d82c/tensorflow/docs_src/tutorials/recurrent.md#stacking-multiple-lstms) [`tf.contrib.rnn.LSTMCell`](https://www.tensorflow.org/api_docs/python/tf/contrib/rnn/LSTMCell) wrapped in a [`tf.contrib.rnn.DropoutWrapper`](https://www.tensorflow.org/api_docs/python/tf/contrib/rnn/DropoutWrapper)
#  * Pass cell and embedded input to [`tf.nn.dynamic_rnn()`](https://www.tensorflow.org/api_docs/python/tf/nn/dynamic_rnn)

# %%
from imp import reload
reload(tests)

def encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob, 
                   source_sequence_length, source_vocab_size, 
                   encoding_embedding_size):
    """
    Create encoding layer
    :param rnn_inputs: Inputs for the RNN
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param keep_prob: Dropout keep probability
    :param source_sequence_length: a list of the lengths of each sequence in the batch
    :param source_vocab_size: vocabulary size of source data
    :param encoding_embedding_size: embedding size of source data
    :return: tuple (RNN output, RNN state)
    """
    # TODO: Implement Function
    # Encoder embedding
    enc_embed_input = tf.contrib.layers.embed_sequence(rnn_inputs, source_vocab_size, encoding_embedding_size)
    
     # RNN cell
    def make_cell(rnn_size, keep_prob):
        enc_cell = tf.contrib.rnn.LSTMCell(rnn_size,
                                           initializer=tf.random_uniform_initializer(-0.1, 0.1, seed=2))
        enc_cell = tf.contrib.rnn.DropoutWrapper(enc_cell, output_keep_prob=keep_prob)
        return enc_cell

    enc_cell = tf.contrib.rnn.MultiRNNCell([make_cell(rnn_size, keep_prob) for _ in range(num_layers)])
    
    rnn_output, rnn_state = tf.nn.dynamic_rnn(enc_cell, enc_embed_input, sequence_length=source_sequence_length, dtype=tf.float32)
    
    return (rnn_output, rnn_state)

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_encoding_layer(encoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### Decoding - Training
# Create a training decoding layer:
# * Create a [`tf.contrib.seq2seq.TrainingHelper`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/TrainingHelper)
# * Create a [`tf.contrib.seq2seq.BasicDecoder`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/BasicDecoder)
# * Obtain the decoder outputs from [`tf.contrib.seq2seq.dynamic_decode`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/dynamic_decode)

# %%
def decoding_layer_train(encoder_state, dec_cell, dec_embed_input, 
                         target_sequence_length, max_summary_length, 
                         output_layer, keep_prob):
    """
    Create a decoding layer for training
    :param encoder_state: Encoder State
    :param dec_cell: Decoder RNN Cell
    :param dec_embed_input: Decoder embedded input
    :param target_sequence_length: The lengths of each sequence in the target batch
    :param max_summary_length: The length of the longest sequence in the batch
    :param output_layer: Function to apply the output layer
    :param keep_prob: Dropout keep probability
    :return: BasicDecoderOutput containing training logits and sample_id
    """
    # TODO: Implement Function
    # Helper for the training process. Used by BasicDecoder to read inputs.
    training_helper = tf.contrib.seq2seq.TrainingHelper(inputs=dec_embed_input,
                                                        sequence_length=target_sequence_length,
                                                        time_major=False)


    # Basic decoder
    training_decoder = tf.contrib.seq2seq.BasicDecoder(dec_cell,
                                                       training_helper,
                                                       encoder_state,
                                                       output_layer) 

    # Perform dynamic decoding using the decoder
    training_decoder_output = tf.contrib.seq2seq.dynamic_decode(training_decoder,
                                                                   impute_finished=True,
                                                                   maximum_iterations=max_summary_length)[0]
    return training_decoder_output



"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer_train(decoding_layer_train)
# Out:
# Tests Passed

# %% [markdown]
# ### Decoding - Inference
# Create inference decoder:
# * Create a [`tf.contrib.seq2seq.GreedyEmbeddingHelper`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/GreedyEmbeddingHelper)
# * Create a [`tf.contrib.seq2seq.BasicDecoder`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/BasicDecoder)
# * Obtain the decoder outputs from [`tf.contrib.seq2seq.dynamic_decode`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/dynamic_decode)

# %%
def decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id,
                         end_of_sequence_id, max_target_sequence_length,
                         vocab_size, output_layer, batch_size, keep_prob):
    """
    Create a decoding layer for inference
    :param encoder_state: Encoder state
    :param dec_cell: Decoder RNN Cell
    :param dec_embeddings: Decoder embeddings
    :param start_of_sequence_id: GO ID
    :param end_of_sequence_id: EOS Id
    :param max_target_sequence_length: Maximum length of target sequences
    :param vocab_size: Size of decoder/target vocabulary
    :param decoding_scope: TenorFlow Variable Scope for decoding
    :param output_layer: Function to apply the output layer
    :param batch_size: Batch size
    :param keep_prob: Dropout keep probability
    :return: BasicDecoderOutput containing inference logits and sample_id
    """
    # TODO: Implement Function
    start_ids = tf.tile([start_of_sequence_id], [batch_size])

    # Helper for the inference process.
    inference_helper = tf.contrib.seq2seq.GreedyEmbeddingHelper(dec_embeddings,
                                                            start_ids,
                                                            target_vocab_to_int['<EOS>'])

    # Basic decoder
    inference_decoder = tf.contrib.seq2seq.BasicDecoder(dec_cell,
                                                    inference_helper,
                                                    encoder_state,
                                                    output_layer)

    # Perform dynamic decoding using the decoder
    inference_decoder_output = tf.contrib.seq2seq.dynamic_decode(inference_decoder,
                                                        impute_finished=True,
                                                        maximum_iterations=max_target_sequence_length)[0]
    return inference_decoder_output



"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer_infer(decoding_layer_infer)
# Out:
# Tests Passed

# %% [markdown]
# ### Build the Decoding Layer
# Implement `decoding_layer()` to create a Decoder RNN layer.
#
# * Embed the target sequences
# * Construct the decoder LSTM cell (just like you constructed the encoder cell above)
# * Create an output layer to map the outputs of the decoder to the elements of our vocabulary
# * Use the your `decoding_layer_train(encoder_state, dec_cell, dec_embed_input, target_sequence_length, max_target_sequence_length, output_layer, keep_prob)` function to get the training logits.
# * Use your `decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id, end_of_sequence_id, max_target_sequence_length, vocab_size, output_layer, batch_size, keep_prob)` function to get the inference logits.
#
# Note: You'll need to use [tf.variable_scope](https://www.tensorflow.org/api_docs/python/tf/variable_scope) to share variables between training and inference.

# %%
def decoding_layer(dec_input, encoder_state,
                   target_sequence_length, max_target_sequence_length,
                   rnn_size,
                   num_layers, target_vocab_to_int, target_vocab_size,
                   batch_size, keep_prob, decoding_embedding_size):
    """
    Create decoding layer
    :param dec_input: Decoder input
    :param encoder_state: Encoder state
    :param target_sequence_length: The lengths of each sequence in the target batch
    :param max_target_sequence_length: Maximum length of target sequences
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :param target_vocab_size: Size of target vocabulary
    :param batch_size: The size of the batch
    :param keep_prob: Dropout keep probability
    :param decoding_embedding_size: Decoding embedding size
    :return: Tuple of (Training BasicDecoderOutput, Inference BasicDecoderOutput)
    """
    # TODO: Implement Function
    # 1. Decoder Embedding
    dec_embeddings = tf.Variable(tf.random_uniform([target_vocab_size, decoding_embedding_size]))
    dec_embed_input = tf.nn.embedding_lookup(dec_embeddings, dec_input)

    # 2. Construct the decoder cell
    def make_cell(rnn_size, keep_prob):
        enc_cell = tf.contrib.rnn.LSTMCell(rnn_size,
                                           initializer=tf.random_uniform_initializer(-0.1, 0.1, seed=2))
        enc_cell = tf.contrib.rnn.DropoutWrapper(enc_cell, output_keep_prob=keep_prob)
        return enc_cell

    dec_cell = tf.contrib.rnn.MultiRNNCell([make_cell(rnn_size, keep_prob) for _ in range(num_layers)])
     
    # 3. Dense layer to translate the decoder's output at each time 
    # step into a choice from the target vocabulary
    with tf.variable_scope("decode"):
        output_layer = Dense(target_vocab_size,
                             kernel_initializer = tf.truncated_normal_initializer(mean = 0.0, stddev=0.1))

        training_decoder_output = decoding_layer_train(encoder_state, dec_cell, dec_embed_input, target_sequence_length, max_target_sequence_length, output_layer, keep_prob)
    
    with tf.variable_scope("decode", reuse=True):
        start_of_sequence_id = target_vocab_to_int['<GO>']
        end_of_sequence_id = target_vocab_to_int['<EOS>']

        inference_decoder_output = decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id, end_of_sequence_id, max_target_sequence_length, target_vocab_size, output_layer, batch_size, keep_prob)

    return training_decoder_output, inference_decoder_output


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer(decoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### Build the Neural Network
# Apply the functions you implemented above to:
#
# - Encode the input using your `encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob,  source_sequence_length, source_vocab_size, encoding_embedding_size)`.
# - Process target data using your `process_decoder_input(target_data, target_vocab_to_int, batch_size)` function.
# - Decode the encoded input using your `decoding_layer(dec_input, enc_state, target_sequence_length, max_target_sentence_length, rnn_size, num_layers, target_vocab_to_int, target_vocab_size, batch_size, keep_prob, dec_embedding_size)` function.

# %%
def seq2seq_model(input_data, target_data, keep_prob, batch_size,
                  source_sequence_length, target_sequence_length,
                  max_target_sentence_length,
                  source_vocab_size, target_vocab_size,
                  enc_embedding_size, dec_embedding_size,
                  rnn_size, num_layers, target_vocab_to_int):
    """
    Build the Sequence-to-Sequence part of the neural network
    :param input_data: Input placeholder
    :param target_data: Target placeholder
    :param keep_prob: Dropout keep probability placeholder
    :param batch_size: Batch Size
    :param source_sequence_length: Sequence Lengths of source sequences in the batch
    :param target_sequence_length: Sequence Lengths of target sequences in the batch
    :param source_vocab_size: Source vocabulary size
    :param target_vocab_size: Target vocabulary size
    :param enc_embedding_size: Decoder embedding size
    :param dec_embedding_size: Encoder embedding size
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :return: Tuple of (Training BasicDecoderOutput, Inference BasicDecoderOutput)
    """
    # TODO: Implement Function
    # Pass the input data through the encoder. We'll ignore the encoder output, but use the state
    _, enc_state = encoding_layer(input_data, rnn_size, num_layers, keep_prob, source_sequence_length, source_vocab_size, enc_embedding_size)
    
    # Prepare the target sequences we'll feed to the decoder in training mode
    dec_input = process_decoder_input(target_data, target_vocab_to_int, batch_size)
    
    # Pass encoder state and decoder inputs to the decoders
    training_decoder_output, inference_decoder_output = decoding_layer(dec_input, enc_state, target_sequence_length, max_target_sentence_length, rnn_size, num_layers, target_vocab_to_int, target_vocab_size, batch_size, keep_prob, dec_embedding_size)
    return training_decoder_output, inference_decoder_output


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_seq2seq_model(seq2seq_model)
# Out:
# Tests Passed

# %% [markdown]
# ## Neural Network Training
# ### Hyperparameters
# Tune the following parameters:
#
# - Set `epochs` to the number of epochs.
# - Set `batch_size` to the batch size.
# - Set `rnn_size` to the size of the RNNs.
# - Set `num_layers` to the number of layers.
# - Set `encoding_embedding_size` to the size of the embedding for the encoder.
# - Set `decoding_embedding_size` to the size of the embedding for the decoder.
# - Set `learning_rate` to the learning rate.
# - Set `keep_probability` to the Dropout keep probability
# - Set `display_step` to state how many steps between each debug output statement

# %%
# Number of Epochs
epochs = 10
# Batch Size
batch_size = 512
# RNN Size
rnn_size = 256
# Number of Layers
num_layers = 2
# Embedding Size
encoding_embedding_size = 300
decoding_embedding_size = 300
# Learning Rate
learning_rate = 0.01
# Dropout Keep Probability
keep_probability = 0.5
display_step = 8

# %% [markdown]
# ### Build the Graph
# Build the graph using the neural network you implemented.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_path = 'checkpoints/dev'
(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = helper.load_preprocess()
max_target_sentence_length = max([len(sentence) for sentence in source_int_text])

train_graph = tf.Graph()
with train_graph.as_default():
    input_data, targets, lr, keep_prob, target_sequence_length, max_target_sequence_length, source_sequence_length = model_inputs()

    #sequence_length = tf.placeholder_with_default(max_target_sentence_length, None, name='sequence_length')
    input_shape = tf.shape(input_data)

    train_logits, inference_logits = seq2seq_model(tf.reverse(input_data, [-1]),
                                                   targets,
                                                   keep_prob,
                                                   batch_size,
                                                   source_sequence_length,
                                                   target_sequence_length,
                                                   max_target_sequence_length,
                                                   len(source_vocab_to_int),
                                                   len(target_vocab_to_int),
                                                   encoding_embedding_size,
                                                   decoding_embedding_size,
                                                   rnn_size,
                                                   num_layers,
                                                   target_vocab_to_int)


    training_logits = tf.identity(train_logits.rnn_output, name='logits')
    inference_logits = tf.identity(inference_logits.sample_id, name='predictions')

    masks = tf.sequence_mask(target_sequence_length, max_target_sequence_length, dtype=tf.float32, name='masks')

    with tf.name_scope("optimization"):
        # Loss function
        cost = tf.contrib.seq2seq.sequence_loss(
            training_logits,
            targets,
            masks)

        # Optimizer
        optimizer = tf.train.AdamOptimizer(lr)

        # Gradient Clipping
        gradients = optimizer.compute_gradients(cost)
        capped_gradients = [(tf.clip_by_value(grad, -1., 1.), var) for grad, var in gradients if grad is not None]
        train_op = optimizer.apply_gradients(capped_gradients)

# %% [markdown]
# Batch and pad the source and target sequences

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
def pad_sentence_batch(sentence_batch, pad_int):
    """Pad sentences with <PAD> so that each sentence of a batch has the same length"""
    max_sentence = max([len(sentence) for sentence in sentence_batch])
    return [sentence + [pad_int] * (max_sentence - len(sentence)) for sentence in sentence_batch]


def get_batches(sources, targets, batch_size, source_pad_int, target_pad_int):
    """Batch targets, sources, and the lengths of their sentences together"""
    for batch_i in range(0, len(sources)//batch_size):
        start_i = batch_i * batch_size

        # Slice the right amount for the batch
        sources_batch = sources[start_i:start_i + batch_size]
        targets_batch = targets[start_i:start_i + batch_size]

        # Pad
        pad_sources_batch = np.array(pad_sentence_batch(sources_batch, source_pad_int))
        pad_targets_batch = np.array(pad_sentence_batch(targets_batch, target_pad_int))

        # Need the lengths for the _lengths parameters
        pad_targets_lengths = []
        for target in pad_targets_batch:
            pad_targets_lengths.append(len(target))

        pad_source_lengths = []
        for source in pad_sources_batch:
            pad_source_lengths.append(len(source))

        yield pad_sources_batch, pad_targets_batch, pad_source_lengths, pad_targets_lengths

# %% [markdown]
# ### Train
# Train the neural network on the preprocessed data. If you have a hard time getting a good loss, check the forms to see if anyone is having the same problem.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
def get_accuracy(target, logits):
    """
    Calculate accuracy
    """
    max_seq = max(target.shape[1], logits.shape[1])
    if max_seq - target.shape[1]:
        target = np.pad(
            target,
            [(0,0),(0,max_seq - target.shape[1])],
            'constant')
    if max_seq - logits.shape[1]:
        logits = np.pad(
            logits,
            [(0,0),(0,max_seq - logits.shape[1])],
            'constant')

    return np.mean(np.equal(target, logits))

# Split data to training and validation sets
train_source = source_int_text[batch_size:]
train_target = target_int_text[batch_size:]
valid_source = source_int_text[:batch_size]
valid_target = target_int_text[:batch_size]
(valid_sources_batch, valid_targets_batch, valid_sources_lengths, valid_targets_lengths ) = next(get_batches(valid_source,
                                                                                                             valid_target,
                                                                                                             batch_size,
                                                                                                             source_vocab_to_int['<PAD>'],
                                                                                                             target_vocab_to_int['<PAD>']))                                                                                                  
with tf.Session(graph=train_graph) as sess:
    sess.run(tf.global_variables_initializer())

    for epoch_i in range(epochs):
        for batch_i, (source_batch, target_batch, sources_lengths, targets_lengths) in enumerate(
                get_batches(train_source, train_target, batch_size,
                            source_vocab_to_int['<PAD>'],
                            target_vocab_to_int['<PAD>'])):

            _, loss = sess.run(
                [train_op, cost],
                {input_data: source_batch,
                 targets: target_batch,
                 lr: learning_rate,
                 target_sequence_length: targets_lengths,
                 source_sequence_length: sources_lengths,
                 keep_prob: keep_probability})


            if batch_i % display_step == 0 and batch_i > 0:


                batch_train_logits = sess.run(
                    inference_logits,
                    {input_data: source_batch,
                     source_sequence_length: sources_lengths,
                     target_sequence_length: targets_lengths,
                     keep_prob: 1.0})


                batch_valid_logits = sess.run(
                    inference_logits,
                    {input_data: valid_sources_batch,
                     source_sequence_length: valid_sources_lengths,
                     target_sequence_length: valid_targets_lengths,
                     keep_prob: 1.0})

                train_acc = get_accuracy(target_batch, batch_train_logits)

                valid_acc = get_accuracy(valid_targets_batch, batch_valid_logits)

                print('Epoch {:>3} Batch {:>4}/{} - Train Accuracy: {:>6.4f}, Validation Accuracy: {:>6.4f}, Loss: {:>6.4f}'
                      .format(epoch_i, batch_i, len(source_int_text) // batch_size, train_acc, valid_acc, loss))

    # Save Model
    saver = tf.train.Saver()
    saver.save(sess, save_path)
    print('Model Trained and Saved')
# Out:
# Epoch   0 Batch    8/269 - Train Accuracy: 0.3163, Validation Accuracy: 0.3782, Loss: 3.4310
# Epoch   0 Batch   16/269 - Train Accuracy: 0.3714, Validation Accuracy: 0.3983, Loss: 2.8714
# Epoch   0 Batch   24/269 - Train Accuracy: 0.3948, Validation Accuracy: 0.4522, Loss: 2.6991
# Epoch   0 Batch   32/269 - Train Accuracy: 0.4584, Validation Accuracy: 0.4856, Loss: 2.3281
# Epoch   0 Batch   40/269 - Train Accuracy: 0.4859, Validation Accuracy: 0.5278, Loss: 2.1752
# Epoch   0 Batch   48/269 - Train Accuracy: 0.5276, Validation Accuracy: 0.5466, Loss: 1.7697
# Epoch   0 Batch   56/269 - Train Accuracy: 0.5541, Validation Accuracy: 0.5613, Loss: 1.5778
# Epoch   0 Batch   64/269 - Train Accuracy: 0.5296, Validation Accuracy: 0.5529, Loss: 1.3531
# Epoch   0 Batch   72/269 - Train Accuracy: 0.5256, Validation Accuracy: 0.5308, Loss: 1.1297
# Epoch   0 Batch   80/269 - Train Accuracy: 0.5509, Validation Accuracy: 0.5520, Loss: 1.0061
# Epoch   0 Batch   88/269 - Train Accuracy: 0.5469, Validation Accuracy: 0.5576, Loss: 0.9348
# Epoch   0 Batch   96/269 - Train Accuracy: 0.5498, Validation Accuracy: 0.5497, Loss: 0.8473
# Epoch   0 Batch  104/269 - Train Accuracy: 0.5565, Validation Accuracy: 0.5589, Loss: 0.8119
# Epoch   0 Batch  112/269 - Train Accuracy: 0.5601, Validation Accuracy: 0.5619, Loss: 0.7673
# Epoch   0 Batch  120/269 - Train Accuracy: 0.5714, Validation Accuracy: 0.5844, Loss: 0.7725
# Epoch   0 Batch  128/269 - Train Accuracy: 0.6010, Validation Accuracy: 0.5794, Loss: 0.7086
# Epoch   0 Batch  136/269 - Train Accuracy: 0.5837, Validation Accuracy: 0.5960, Loss: 0.7521
# Epoch   0 Batch  144/269 - Train Accuracy: 0.6244, Validation Accuracy: 0.6223, Loss: 0.6574
# Epoch   0 Batch  152/269 - Train Accuracy: 0.6148, Validation Accuracy: 0.6151, Loss: 0.6649
# Epoch   0 Batch  160/269 - Train Accuracy: 0.6338, Validation Accuracy: 0.6256, Loss: 0.6435
# Epoch   0 Batch  168/269 - Train Accuracy: 0.6243, Validation Accuracy: 0.6386, Loss: 0.6319
# Epoch   0 Batch  176/269 - Train Accuracy: 0.6049, Validation Accuracy: 0.6264, Loss: 0.6568
# Epoch   0 Batch  184/269 - Train Accuracy: 0.6276, Validation Accuracy: 0.6324, Loss: 0.6409
# Epoch   0 Batch  192/269 - Train Accuracy: 0.6368, Validation Accuracy: 0.6366, Loss: 0.5930
# Epoch   0 Batch  200/269 - Train Accuracy: 0.6409, Validation Accuracy: 0.6561, Loss: 0.6041
# Epoch   0 Batch  208/269 - Train Accuracy: 0.6305, Validation Accuracy: 0.6580, Loss: 0.5866
# Epoch   0 Batch  216/269 - Train Accuracy: 0.6234, Validation Accuracy: 0.6648, Loss: 0.5880
# Epoch   0 Batch  224/269 - Train Accuracy: 0.6794, Validation Accuracy: 0.6804, Loss: 0.5607
# Epoch   0 Batch  232/269 - Train Accuracy: 0.6512, Validation Accuracy: 0.6777, Loss: 0.5576
# Epoch   0 Batch  240/269 - Train Accuracy: 0.7068, Validation Accuracy: 0.6867, Loss: 0.4739
# Epoch   0 Batch  248/269 - Train Accuracy: 0.6837, Validation Accuracy: 0.6903, Loss: 0.5029
# Epoch   0 Batch  256/269 - Train Accuracy: 0.6880, Validation Accuracy: 0.6944, Loss: 0.5044
# Epoch   0 Batch  264/269 - Train Accuracy: 0.6776, Validation Accuracy: 0.7087, Loss: 0.5099
# Epoch   1 Batch    8/269 - Train Accuracy: 0.6812, Validation Accuracy: 0.7117, Loss: 0.5081
# Epoch   1 Batch   16/269 - Train Accuracy: 0.7134, Validation Accuracy: 0.7203, Loss: 0.4756
# Epoch   1 Batch   24/269 - Train Accuracy: 0.7200, Validation Accuracy: 0.7226, Loss: 0.4756
# Epoch   1 Batch   32/269 - Train Accuracy: 0.7371, Validation Accuracy: 0.7323, Loss: 0.4259
# Epoch   1 Batch   40/269 - Train Accuracy: 0.7172, Validation Accuracy: 0.7262, Loss: 0.4553
# Epoch   1 Batch   48/269 - Train Accuracy: 0.7666, Validation Accuracy: 0.7584, Loss: 0.4021
# Epoch   1 Batch   56/269 - Train Accuracy: 0.7500, Validation Accuracy: 0.7467, Loss: 0.3961
# Epoch   1 Batch   64/269 - Train Accuracy: 0.7583, Validation Accuracy: 0.7608, Loss: 0.3802
# Epoch   1 Batch   72/269 - Train Accuracy: 0.7718, Validation Accuracy: 0.7642, Loss: 0.3780
# Epoch   1 Batch   80/269 - Train Accuracy: 0.7767, Validation Accuracy: 0.7663, Loss: 0.3616
# Epoch   1 Batch   88/269 - Train Accuracy: 0.7460, Validation Accuracy: 0.7691, Loss: 0.3496
# Epoch   1 Batch   96/269 - Train Accuracy: 0.7626, Validation Accuracy: 0.7809, Loss: 0.3426
# Epoch   1 Batch  104/269 - Train Accuracy: 0.7801, Validation Accuracy: 0.7810, Loss: 0.3293
# Epoch   1 Batch  112/269 - Train Accuracy: 0.7839, Validation Accuracy: 0.7832, Loss: 0.3159
# Epoch   1 Batch  120/269 - Train Accuracy: 0.7896, Validation Accuracy: 0.7989, Loss: 0.3275
# Epoch   1 Batch  128/269 - Train Accuracy: 0.7935, Validation Accuracy: 0.7864, Loss: 0.2984
# Epoch   1 Batch  136/269 - Train Accuracy: 0.7821, Validation Accuracy: 0.8034, Loss: 0.3195
# Epoch   1 Batch  144/269 - Train Accuracy: 0.8130, Validation Accuracy: 0.8052, Loss: 0.2714
# Epoch   1 Batch  152/269 - Train Accuracy: 0.8163, Validation Accuracy: 0.8098, Loss: 0.2788
# Epoch   1 Batch  160/269 - Train Accuracy: 0.8255, Validation Accuracy: 0.8243, Loss: 0.2753
# Epoch   1 Batch  168/269 - Train Accuracy: 0.8195, Validation Accuracy: 0.8232, Loss: 0.2735
# Epoch   1 Batch  176/269 - Train Accuracy: 0.8081, Validation Accuracy: 0.8216, Loss: 0.2665
# Epoch   1 Batch  184/269 - Train Accuracy: 0.8386, Validation Accuracy: 0.8402, Loss: 0.2565
# Epoch   1 Batch  192/269 - Train Accuracy: 0.8529, Validation Accuracy: 0.8355, Loss: 0.2426
# Epoch   1 Batch  200/269 - Train Accuracy: 0.8409, Validation Accuracy: 0.8362, Loss: 0.2379
# Epoch   1 Batch  208/269 - Train Accuracy: 0.8402, Validation Accuracy: 0.8401, Loss: 0.2302
# Epoch   1 Batch  216/269 - Train Accuracy: 0.8272, Validation Accuracy: 0.8495, Loss: 0.2459
# Epoch   1 Batch  224/269 - Train Accuracy: 0.8534, Validation Accuracy: 0.8579, Loss: 0.2279
# Epoch   1 Batch  232/269 - Train Accuracy: 0.8495, Validation Accuracy: 0.8548, Loss: 0.2158
# Epoch   1 Batch  240/269 - Train Accuracy: 0.8676, Validation Accuracy: 0.8611, Loss: 0.1854
# Epoch   1 Batch  248/269 - Train Accuracy: 0.8630, Validation Accuracy: 0.8616, Loss: 0.1947
# Epoch   1 Batch  256/269 - Train Accuracy: 0.8475, Validation Accuracy: 0.8600, Loss: 0.1980
# Epoch   1 Batch  264/269 - Train Accuracy: 0.8334, Validation Accuracy: 0.8648, Loss: 0.1976
# Epoch   2 Batch    8/269 - Train Accuracy: 0.8689, Validation Accuracy: 0.8588, Loss: 0.1945
# Epoch   2 Batch   16/269 - Train Accuracy: 0.8600, Validation Accuracy: 0.8662, Loss: 0.1866
# Epoch   2 Batch   24/269 - Train Accuracy: 0.8764, Validation Accuracy: 0.8788, Loss: 0.1721
# Epoch   2 Batch   32/269 - Train Accuracy: 0.8823, Validation Accuracy: 0.8675, Loss: 0.1581
# Epoch   2 Batch   40/269 - Train Accuracy: 0.8689, Validation Accuracy: 0.8777, Loss: 0.1694
# Epoch   2 Batch   48/269 - Train Accuracy: 0.8876, Validation Accuracy: 0.8824, Loss: 0.1567
# Epoch   2 Batch   56/269 - Train Accuracy: 0.8713, Validation Accuracy: 0.8714, Loss: 0.1566
# Epoch   2 Batch   64/269 - Train Accuracy: 0.8976, Validation Accuracy: 0.8722, Loss: 0.1401
# Epoch   2 Batch   72/269 - Train Accuracy: 0.8746, Validation Accuracy: 0.8858, Loss: 0.1456
# Epoch   2 Batch   80/269 - Train Accuracy: 0.8946, Validation Accuracy: 0.8824, Loss: 0.1367
# Epoch   2 Batch   88/269 - Train Accuracy: 0.8731, Validation Accuracy: 0.8847, Loss: 0.1434
# Epoch   2 Batch   96/269 - Train Accuracy: 0.8783, Validation Accuracy: 0.8833, Loss: 0.1374
# Epoch   2 Batch  104/269 - Train Accuracy: 0.8949, Validation Accuracy: 0.8929, Loss: 0.1293
# Epoch   2 Batch  112/269 - Train Accuracy: 0.8966, Validation Accuracy: 0.8929, Loss: 0.1338
# Epoch   2 Batch  120/269 - Train Accuracy: 0.8941, Validation Accuracy: 0.8939, Loss: 0.1291
# Epoch   2 Batch  128/269 - Train Accuracy: 0.8930, Validation Accuracy: 0.8937, Loss: 0.1267
# Epoch   2 Batch  136/269 - Train Accuracy: 0.8797, Validation Accuracy: 0.9019, Loss: 0.1393
# Epoch   2 Batch  144/269 - Train Accuracy: 0.9089, Validation Accuracy: 0.8982, Loss: 0.1100
# Epoch   2 Batch  152/269 - Train Accuracy: 0.9030, Validation Accuracy: 0.9091, Loss: 0.1206
# Epoch   2 Batch  160/269 - Train Accuracy: 0.9090, Validation Accuracy: 0.9070, Loss: 0.1150
# Epoch   2 Batch  168/269 - Train Accuracy: 0.9047, Validation Accuracy: 0.9007, Loss: 0.1169
# Epoch   2 Batch  176/269 - Train Accuracy: 0.8794, Validation Accuracy: 0.9066, Loss: 0.1221
# Epoch   2 Batch  184/269 - Train Accuracy: 0.9125, Validation Accuracy: 0.9086, Loss: 0.1119
# Epoch   2 Batch  192/269 - Train Accuracy: 0.9159, Validation Accuracy: 0.9091, Loss: 0.1058
# Epoch   2 Batch  200/269 - Train Accuracy: 0.9140, Validation Accuracy: 0.9086, Loss: 0.1136
# Epoch   2 Batch  208/269 - Train Accuracy: 0.9020, Validation Accuracy: 0.8991, Loss: 0.1121
# Epoch   2 Batch  216/269 - Train Accuracy: 0.8941, Validation Accuracy: 0.9128, Loss: 0.1139
# Epoch   2 Batch  224/269 - Train Accuracy: 0.9195, Validation Accuracy: 0.9119, Loss: 0.1162
# Epoch   2 Batch  232/269 - Train Accuracy: 0.9118, Validation Accuracy: 0.9131, Loss: 0.0998
# Epoch   2 Batch  240/269 - Train Accuracy: 0.9170, Validation Accuracy: 0.9085, Loss: 0.0867
# Epoch   2 Batch  248/269 - Train Accuracy: 0.9097, Validation Accuracy: 0.9119, Loss: 0.0934
# Epoch   2 Batch  256/269 - Train Accuracy: 0.9050, Validation Accuracy: 0.9103, Loss: 0.0981
# Epoch   2 Batch  264/269 - Train Accuracy: 0.8933, Validation Accuracy: 0.9090, Loss: 0.1020
# Epoch   3 Batch    8/269 - Train Accuracy: 0.9325, Validation Accuracy: 0.9081, Loss: 0.0951
# Epoch   3 Batch   16/269 - Train Accuracy: 0.9099, Validation Accuracy: 0.9177, Loss: 0.1031
# Epoch   3 Batch   24/269 - Train Accuracy: 0.9245, Validation Accuracy: 0.9121, Loss: 0.0882
# Epoch   3 Batch   32/269 - Train Accuracy: 0.9275, Validation Accuracy: 0.8993, Loss: 0.0820
# Epoch   3 Batch   40/269 - Train Accuracy: 0.9169, Validation Accuracy: 0.9146, Loss: 0.0974
# Epoch   3 Batch   48/269 - Train Accuracy: 0.9228, Validation Accuracy: 0.9184, Loss: 0.0835
# Epoch   3 Batch   56/269 - Train Accuracy: 0.9159, Validation Accuracy: 0.9180, Loss: 0.0853
# Epoch   3 Batch   64/269 - Train Accuracy: 0.9256, Validation Accuracy: 0.9211, Loss: 0.0798
# Epoch   3 Batch   72/269 - Train Accuracy: 0.9231, Validation Accuracy: 0.9133, Loss: 0.0910
# Epoch   3 Batch   80/269 - Train Accuracy: 0.9208, Validation Accuracy: 0.9276, Loss: 0.0879
# Epoch   3 Batch   88/269 - Train Accuracy: 0.9066, Validation Accuracy: 0.9148, Loss: 0.0874
# Epoch   3 Batch   96/269 - Train Accuracy: 0.9000, Validation Accuracy: 0.9137, Loss: 0.0933
# Epoch   3 Batch  104/269 - Train Accuracy: 0.9256, Validation Accuracy: 0.9211, Loss: 0.0793
# Epoch   3 Batch  112/269 - Train Accuracy: 0.9355, Validation Accuracy: 0.9165, Loss: 0.0809
# Epoch   3 Batch  120/269 - Train Accuracy: 0.9245, Validation Accuracy: 0.9210, Loss: 0.0832
# Epoch   3 Batch  128/269 - Train Accuracy: 0.9203, Validation Accuracy: 0.9169, Loss: 0.0781
# Epoch   3 Batch  136/269 - Train Accuracy: 0.8950, Validation Accuracy: 0.9301, Loss: 0.0905
# Epoch   3 Batch  144/269 - Train Accuracy: 0.9407, Validation Accuracy: 0.9220, Loss: 0.0653
# Epoch   3 Batch  152/269 - Train Accuracy: 0.9214, Validation Accuracy: 0.9278, Loss: 0.0732
# Epoch   3 Batch  160/269 - Train Accuracy: 0.9309, Validation Accuracy: 0.9287, Loss: 0.0726
# Epoch   3 Batch  168/269 - Train Accuracy: 0.9239, Validation Accuracy: 0.9245, Loss: 0.0796
# Epoch   3 Batch  176/269 - Train Accuracy: 0.9131, Validation Accuracy: 0.9269, Loss: 0.0778
# Epoch   3 Batch  184/269 - Train Accuracy: 0.9348, Validation Accuracy: 0.9242, Loss: 0.0772
# Epoch   3 Batch  192/269 - Train Accuracy: 0.9357, Validation Accuracy: 0.9244, Loss: 0.0723
# Epoch   3 Batch  200/269 - Train Accuracy: 0.9337, Validation Accuracy: 0.9245, Loss: 0.0759
# Epoch   3 Batch  208/269 - Train Accuracy: 0.9353, Validation Accuracy: 0.9238, Loss: 0.0801
# Epoch   3 Batch  216/269 - Train Accuracy: 0.9123, Validation Accuracy: 0.9337, Loss: 0.0891
# Epoch   3 Batch  224/269 - Train Accuracy: 0.9299, Validation Accuracy: 0.9300, Loss: 0.0843
# Epoch   3 Batch  232/269 - Train Accuracy: 0.9308, Validation Accuracy: 0.9351, Loss: 0.0656
# Epoch   3 Batch  240/269 - Train Accuracy: 0.9329, Validation Accuracy: 0.9317, Loss: 0.0655
# Epoch   3 Batch  248/269 - Train Accuracy: 0.9238, Validation Accuracy: 0.9285, Loss: 0.0682
# Epoch   3 Batch  256/269 - Train Accuracy: 0.9230, Validation Accuracy: 0.9238, Loss: 0.0675
# Epoch   3 Batch  264/269 - Train Accuracy: 0.9128, Validation Accuracy: 0.9312, Loss: 0.0724
# Epoch   4 Batch    8/269 - Train Accuracy: 0.9445, Validation Accuracy: 0.9332, Loss: 0.0734
# Epoch   4 Batch   16/269 - Train Accuracy: 0.9172, Validation Accuracy: 0.9222, Loss: 0.0725
# Epoch   4 Batch   24/269 - Train Accuracy: 0.9321, Validation Accuracy: 0.9338, Loss: 0.0623
# Epoch   4 Batch   32/269 - Train Accuracy: 0.9467, Validation Accuracy: 0.9284, Loss: 0.0556
# Epoch   4 Batch   40/269 - Train Accuracy: 0.9334, Validation Accuracy: 0.9299, Loss: 0.0655
# Epoch   4 Batch   48/269 - Train Accuracy: 0.9391, Validation Accuracy: 0.9333, Loss: 0.0650
# Epoch   4 Batch   56/269 - Train Accuracy: 0.9306, Validation Accuracy: 0.9379, Loss: 0.0716
# Epoch   4 Batch   64/269 - Train Accuracy: 0.9373, Validation Accuracy: 0.9362, Loss: 0.0624
# Epoch   4 Batch   72/269 - Train Accuracy: 0.9258, Validation Accuracy: 0.9272, Loss: 0.0680
# Epoch   4 Batch   80/269 - Train Accuracy: 0.9399, Validation Accuracy: 0.9433, Loss: 0.0644
# Epoch   4 Batch   88/269 - Train Accuracy: 0.9250, Validation Accuracy: 0.9300, Loss: 0.0661
# Epoch   4 Batch   96/269 - Train Accuracy: 0.9194, Validation Accuracy: 0.9370, Loss: 0.0665
# Epoch   4 Batch  104/269 - Train Accuracy: 0.9421, Validation Accuracy: 0.9269, Loss: 0.0614
# Epoch   4 Batch  112/269 - Train Accuracy: 0.9324, Validation Accuracy: 0.9184, Loss: 0.0652
# Epoch   4 Batch  120/269 - Train Accuracy: 0.9422, Validation Accuracy: 0.9382, Loss: 0.0680
# Epoch   4 Batch  128/269 - Train Accuracy: 0.9336, Validation Accuracy: 0.9352, Loss: 0.0625
# Epoch   4 Batch  136/269 - Train Accuracy: 0.9181, Validation Accuracy: 0.9439, Loss: 0.0698
# Epoch   4 Batch  144/269 - Train Accuracy: 0.9541, Validation Accuracy: 0.9377, Loss: 0.0514
# Epoch   4 Batch  152/269 - Train Accuracy: 0.9381, Validation Accuracy: 0.9363, Loss: 0.0588
# Epoch   4 Batch  160/269 - Train Accuracy: 0.9433, Validation Accuracy: 0.9380, Loss: 0.0620
# Epoch   4 Batch  168/269 - Train Accuracy: 0.9379, Validation Accuracy: 0.9434, Loss: 0.0660
# Epoch   4 Batch  176/269 - Train Accuracy: 0.9247, Validation Accuracy: 0.9401, Loss: 0.0651
# Epoch   4 Batch  184/269 - Train Accuracy: 0.9406, Validation Accuracy: 0.9414, Loss: 0.0565
# Epoch   4 Batch  192/269 - Train Accuracy: 0.9546, Validation Accuracy: 0.9379, Loss: 0.0525
# Epoch   4 Batch  200/269 - Train Accuracy: 0.9501, Validation Accuracy: 0.9317, Loss: 0.0575
# Epoch   4 Batch  208/269 - Train Accuracy: 0.9375, Validation Accuracy: 0.9400, Loss: 0.0654
# Epoch   4 Batch  216/269 - Train Accuracy: 0.9308, Validation Accuracy: 0.9399, Loss: 0.0665
# Epoch   4 Batch  224/269 - Train Accuracy: 0.9448, Validation Accuracy: 0.9466, Loss: 0.0692
# Epoch   4 Batch  232/269 - Train Accuracy: 0.9437, Validation Accuracy: 0.9476, Loss: 0.0555
# Epoch   4 Batch  240/269 - Train Accuracy: 0.9505, Validation Accuracy: 0.9399, Loss: 0.0501
# Epoch   4 Batch  248/269 - Train Accuracy: 0.9504, Validation Accuracy: 0.9430, Loss: 0.0517
# Epoch   4 Batch  256/269 - Train Accuracy: 0.9336, Validation Accuracy: 0.9375, Loss: 0.0530
# Epoch   4 Batch  264/269 - Train Accuracy: 0.9397, Validation Accuracy: 0.9455, Loss: 0.0549
# Epoch   5 Batch    8/269 - Train Accuracy: 0.9527, Validation Accuracy: 0.9374, Loss: 0.0550
# Epoch   5 Batch   16/269 - Train Accuracy: 0.9301, Validation Accuracy: 0.9440, Loss: 0.0589
# Epoch   5 Batch   24/269 - Train Accuracy: 0.9338, Validation Accuracy: 0.9356, Loss: 0.0520
# Epoch   5 Batch   32/269 - Train Accuracy: 0.9557, Validation Accuracy: 0.9385, Loss: 0.0459
# Epoch   5 Batch   40/269 - Train Accuracy: 0.9408, Validation Accuracy: 0.9464, Loss: 0.0565
# Epoch   5 Batch   48/269 - Train Accuracy: 0.9544, Validation Accuracy: 0.9435, Loss: 0.0502
# Epoch   5 Batch   56/269 - Train Accuracy: 0.9355, Validation Accuracy: 0.9431, Loss: 0.0526
# Epoch   5 Batch   64/269 - Train Accuracy: 0.9498, Validation Accuracy: 0.9461, Loss: 0.0440
# Epoch   5 Batch   72/269 - Train Accuracy: 0.9461, Validation Accuracy: 0.9390, Loss: 0.0577
# Epoch   5 Batch   80/269 - Train Accuracy: 0.9549, Validation Accuracy: 0.9454, Loss: 0.0477
# Epoch   5 Batch   88/269 - Train Accuracy: 0.9313, Validation Accuracy: 0.9354, Loss: 0.0558
# Epoch   5 Batch   96/269 - Train Accuracy: 0.9316, Validation Accuracy: 0.9499, Loss: 0.0541
# Epoch   5 Batch  104/269 - Train Accuracy: 0.9602, Validation Accuracy: 0.9528, Loss: 0.0511
# Epoch   5 Batch  112/269 - Train Accuracy: 0.9579, Validation Accuracy: 0.9451, Loss: 0.0497
# Epoch   5 Batch  120/269 - Train Accuracy: 0.9442, Validation Accuracy: 0.9529, Loss: 0.0519
# Epoch   5 Batch  128/269 - Train Accuracy: 0.9489, Validation Accuracy: 0.9411, Loss: 0.0504
# Epoch   5 Batch  136/269 - Train Accuracy: 0.9328, Validation Accuracy: 0.9478, Loss: 0.0540
# Epoch   5 Batch  144/269 - Train Accuracy: 0.9538, Validation Accuracy: 0.9394, Loss: 0.0432
# Epoch   5 Batch  152/269 - Train Accuracy: 0.9516, Validation Accuracy: 0.9440, Loss: 0.0519
# Epoch   5 Batch  160/269 - Train Accuracy: 0.9550, Validation Accuracy: 0.9546, Loss: 0.0463
# Epoch   5 Batch  168/269 - Train Accuracy: 0.9472, Validation Accuracy: 0.9513, Loss: 0.0508
# Epoch   5 Batch  176/269 - Train Accuracy: 0.9311, Validation Accuracy: 0.9549, Loss: 0.0508
# Epoch   5 Batch  184/269 - Train Accuracy: 0.9547, Validation Accuracy: 0.9484, Loss: 0.0454
# Epoch   5 Batch  192/269 - Train Accuracy: 0.9599, Validation Accuracy: 0.9476, Loss: 0.0500
# Epoch   5 Batch  200/269 - Train Accuracy: 0.9549, Validation Accuracy: 0.9455, Loss: 0.0476
# Epoch   5 Batch  208/269 - Train Accuracy: 0.9605, Validation Accuracy: 0.9445, Loss: 0.0515
# Epoch   5 Batch  216/269 - Train Accuracy: 0.9441, Validation Accuracy: 0.9484, Loss: 0.0539
# Epoch   5 Batch  224/269 - Train Accuracy: 0.9540, Validation Accuracy: 0.9497, Loss: 0.0535
# Epoch   5 Batch  232/269 - Train Accuracy: 0.9535, Validation Accuracy: 0.9587, Loss: 0.0423
# Epoch   5 Batch  240/269 - Train Accuracy: 0.9634, Validation Accuracy: 0.9585, Loss: 0.0401
# Epoch   5 Batch  248/269 - Train Accuracy: 0.9568, Validation Accuracy: 0.9562, Loss: 0.0412
# Epoch   5 Batch  256/269 - Train Accuracy: 0.9458, Validation Accuracy: 0.9550, Loss: 0.0451
# Epoch   5 Batch  264/269 - Train Accuracy: 0.9404, Validation Accuracy: 0.9483, Loss: 0.0510
# Epoch   6 Batch    8/269 - Train Accuracy: 0.9569, Validation Accuracy: 0.9506, Loss: 0.0488
# Epoch   6 Batch   16/269 - Train Accuracy: 0.9352, Validation Accuracy: 0.9479, Loss: 0.0521
# Epoch   6 Batch   24/269 - Train Accuracy: 0.9535, Validation Accuracy: 0.9510, Loss: 0.0444
# Epoch   6 Batch   32/269 - Train Accuracy: 0.9575, Validation Accuracy: 0.9483, Loss: 0.0412
# Epoch   6 Batch   40/269 - Train Accuracy: 0.9363, Validation Accuracy: 0.9527, Loss: 0.0472
# Epoch   6 Batch   48/269 - Train Accuracy: 0.9566, Validation Accuracy: 0.9474, Loss: 0.0414
# Epoch   6 Batch   56/269 - Train Accuracy: 0.9495, Validation Accuracy: 0.9509, Loss: 0.0423
# Epoch   6 Batch   64/269 - Train Accuracy: 0.9527, Validation Accuracy: 0.9532, Loss: 0.0430
# Epoch   6 Batch   72/269 - Train Accuracy: 0.9562, Validation Accuracy: 0.9545, Loss: 0.0497
# Epoch   6 Batch   80/269 - Train Accuracy: 0.9597, Validation Accuracy: 0.9520, Loss: 0.0400
# Epoch   6 Batch   88/269 - Train Accuracy: 0.9350, Validation Accuracy: 0.9512, Loss: 0.0462
# Epoch   6 Batch   96/269 - Train Accuracy: 0.9409, Validation Accuracy: 0.9532, Loss: 0.0487
# Epoch   6 Batch  104/269 - Train Accuracy: 0.9505, Validation Accuracy: 0.9523, Loss: 0.0412
# Epoch   6 Batch  112/269 - Train Accuracy: 0.9539, Validation Accuracy: 0.9542, Loss: 0.0518
# Epoch   6 Batch  120/269 - Train Accuracy: 0.9535, Validation Accuracy: 0.9475, Loss: 0.0516
# Epoch   6 Batch  128/269 - Train Accuracy: 0.9501, Validation Accuracy: 0.9526, Loss: 0.0488
# Epoch   6 Batch  136/269 - Train Accuracy: 0.9370, Validation Accuracy: 0.9576, Loss: 0.0512
# Epoch   6 Batch  144/269 - Train Accuracy: 0.9658, Validation Accuracy: 0.9607, Loss: 0.0359
# Epoch   6 Batch  152/269 - Train Accuracy: 0.9515, Validation Accuracy: 0.9545, Loss: 0.0430
# Epoch   6 Batch  160/269 - Train Accuracy: 0.9621, Validation Accuracy: 0.9548, Loss: 0.0433
# Epoch   6 Batch  168/269 - Train Accuracy: 0.9489, Validation Accuracy: 0.9550, Loss: 0.0464
# Epoch   6 Batch  176/269 - Train Accuracy: 0.9471, Validation Accuracy: 0.9549, Loss: 0.0480
# Epoch   6 Batch  184/269 - Train Accuracy: 0.9655, Validation Accuracy: 0.9580, Loss: 0.0392
# Epoch   6 Batch  192/269 - Train Accuracy: 0.9660, Validation Accuracy: 0.9624, Loss: 0.0410
# Epoch   6 Batch  200/269 - Train Accuracy: 0.9588, Validation Accuracy: 0.9566, Loss: 0.0410
# Epoch   6 Batch  208/269 - Train Accuracy: 0.9566, Validation Accuracy: 0.9504, Loss: 0.0442
# Epoch   6 Batch  216/269 - Train Accuracy: 0.9443, Validation Accuracy: 0.9598, Loss: 0.0539
# Epoch   6 Batch  224/269 - Train Accuracy: 0.9560, Validation Accuracy: 0.9567, Loss: 0.0459
# Epoch   6 Batch  232/269 - Train Accuracy: 0.9516, Validation Accuracy: 0.9554, Loss: 0.0511
# Epoch   6 Batch  240/269 - Train Accuracy: 0.9592, Validation Accuracy: 0.9553, Loss: 0.0387
# Epoch   6 Batch  248/269 - Train Accuracy: 0.9599, Validation Accuracy: 0.9505, Loss: 0.0380
# Epoch   6 Batch  256/269 - Train Accuracy: 0.9496, Validation Accuracy: 0.9457, Loss: 0.0380
# Epoch   6 Batch  264/269 - Train Accuracy: 0.9363, Validation Accuracy: 0.9570, Loss: 0.0491
# Epoch   7 Batch    8/269 - Train Accuracy: 0.9607, Validation Accuracy: 0.9510, Loss: 0.0477
# Epoch   7 Batch   16/269 - Train Accuracy: 0.9510, Validation Accuracy: 0.9599, Loss: 0.0418
# Epoch   7 Batch   24/269 - Train Accuracy: 0.9506, Validation Accuracy: 0.9522, Loss: 0.0378
# Epoch   7 Batch   32/269 - Train Accuracy: 0.9574, Validation Accuracy: 0.9479, Loss: 0.0344
# Epoch   7 Batch   40/269 - Train Accuracy: 0.9526, Validation Accuracy: 0.9582, Loss: 0.0434
# Epoch   7 Batch   48/269 - Train Accuracy: 0.9570, Validation Accuracy: 0.9598, Loss: 0.0377
# Epoch   7 Batch   56/269 - Train Accuracy: 0.9513, Validation Accuracy: 0.9552, Loss: 0.0407
# Epoch   7 Batch   64/269 - Train Accuracy: 0.9589, Validation Accuracy: 0.9623, Loss: 0.0331
# Epoch   7 Batch   72/269 - Train Accuracy: 0.9525, Validation Accuracy: 0.9599, Loss: 0.0466
# Epoch   7 Batch   80/269 - Train Accuracy: 0.9540, Validation Accuracy: 0.9609, Loss: 0.0399
# Epoch   7 Batch   88/269 - Train Accuracy: 0.9478, Validation Accuracy: 0.9500, Loss: 0.0434
# Epoch   7 Batch   96/269 - Train Accuracy: 0.9507, Validation Accuracy: 0.9571, Loss: 0.0464
# Epoch   7 Batch  104/269 - Train Accuracy: 0.9538, Validation Accuracy: 0.9535, Loss: 0.0371
# Epoch   7 Batch  112/269 - Train Accuracy: 0.9613, Validation Accuracy: 0.9599, Loss: 0.0416
# Epoch   7 Batch  120/269 - Train Accuracy: 0.9476, Validation Accuracy: 0.9609, Loss: 0.0413
# Epoch   7 Batch  128/269 - Train Accuracy: 0.9547, Validation Accuracy: 0.9569, Loss: 0.0387
# Epoch   7 Batch  136/269 - Train Accuracy: 0.9426, Validation Accuracy: 0.9567, Loss: 0.0470
# Epoch   7 Batch  144/269 - Train Accuracy: 0.9703, Validation Accuracy: 0.9518, Loss: 0.0324
# Epoch   7 Batch  152/269 - Train Accuracy: 0.9592, Validation Accuracy: 0.9627, Loss: 0.0433
# Epoch   7 Batch  160/269 - Train Accuracy: 0.9528, Validation Accuracy: 0.9619, Loss: 0.0380
# Epoch   7 Batch  168/269 - Train Accuracy: 0.9568, Validation Accuracy: 0.9554, Loss: 0.0403
# Epoch   7 Batch  176/269 - Train Accuracy: 0.9480, Validation Accuracy: 0.9566, Loss: 0.0464
# Epoch   7 Batch  184/269 - Train Accuracy: 0.9648, Validation Accuracy: 0.9561, Loss: 0.0425
# Epoch   7 Batch  192/269 - Train Accuracy: 0.9683, Validation Accuracy: 0.9551, Loss: 0.0418
# Epoch   7 Batch  200/269 - Train Accuracy: 0.9700, Validation Accuracy: 0.9550, Loss: 0.0352
# Epoch   7 Batch  208/269 - Train Accuracy: 0.9606, Validation Accuracy: 0.9569, Loss: 0.0418
# Epoch   7 Batch  216/269 - Train Accuracy: 0.9398, Validation Accuracy: 0.9612, Loss: 0.0535
# Epoch   7 Batch  224/269 - Train Accuracy: 0.9536, Validation Accuracy: 0.9559, Loss: 0.0533
# Epoch   7 Batch  232/269 - Train Accuracy: 0.9554, Validation Accuracy: 0.9523, Loss: 0.0380
# Epoch   7 Batch  240/269 - Train Accuracy: 0.9639, Validation Accuracy: 0.9566, Loss: 0.0395
# Epoch   7 Batch  248/269 - Train Accuracy: 0.9695, Validation Accuracy: 0.9537, Loss: 0.0392
# Epoch   7 Batch  256/269 - Train Accuracy: 0.9545, Validation Accuracy: 0.9568, Loss: 0.0443
# Epoch   7 Batch  264/269 - Train Accuracy: 0.9468, Validation Accuracy: 0.9638, Loss: 0.0435
# Epoch   8 Batch    8/269 - Train Accuracy: 0.9595, Validation Accuracy: 0.9644, Loss: 0.0465
# Epoch   8 Batch   16/269 - Train Accuracy: 0.9539, Validation Accuracy: 0.9566, Loss: 0.0434
# Epoch   8 Batch   24/269 - Train Accuracy: 0.9561, Validation Accuracy: 0.9555, Loss: 0.0372
# Epoch   8 Batch   32/269 - Train Accuracy: 0.9668, Validation Accuracy: 0.9574, Loss: 0.0330
# Epoch   8 Batch   40/269 - Train Accuracy: 0.9569, Validation Accuracy: 0.9641, Loss: 0.0421
# Epoch   8 Batch   48/269 - Train Accuracy: 0.9601, Validation Accuracy: 0.9580, Loss: 0.0362
# Epoch   8 Batch   56/269 - Train Accuracy: 0.9458, Validation Accuracy: 0.9575, Loss: 0.0413
# Epoch   8 Batch   64/269 - Train Accuracy: 0.9641, Validation Accuracy: 0.9672, Loss: 0.0368
# Epoch   8 Batch   72/269 - Train Accuracy: 0.9537, Validation Accuracy: 0.9550, Loss: 0.0439
# Epoch   8 Batch   80/269 - Train Accuracy: 0.9612, Validation Accuracy: 0.9624, Loss: 0.0399
# Epoch   8 Batch   88/269 - Train Accuracy: 0.9525, Validation Accuracy: 0.9626, Loss: 0.0381
# Epoch   8 Batch   96/269 - Train Accuracy: 0.9548, Validation Accuracy: 0.9634, Loss: 0.0401
# Epoch   8 Batch  104/269 - Train Accuracy: 0.9563, Validation Accuracy: 0.9569, Loss: 0.0437
# Epoch   8 Batch  112/269 - Train Accuracy: 0.9607, Validation Accuracy: 0.9640, Loss: 0.0398
# Epoch   8 Batch  120/269 - Train Accuracy: 0.9531, Validation Accuracy: 0.9622, Loss: 0.0466
# Epoch   8 Batch  128/269 - Train Accuracy: 0.9623, Validation Accuracy: 0.9584, Loss: 0.0402
# Epoch   8 Batch  136/269 - Train Accuracy: 0.9473, Validation Accuracy: 0.9651, Loss: 0.0460
# Epoch   8 Batch  144/269 - Train Accuracy: 0.9709, Validation Accuracy: 0.9611, Loss: 0.0341
# Epoch   8 Batch  152/269 - Train Accuracy: 0.9636, Validation Accuracy: 0.9552, Loss: 0.0409
# Epoch   8 Batch  160/269 - Train Accuracy: 0.9636, Validation Accuracy: 0.9542, Loss: 0.0409
# Epoch   8 Batch  168/269 - Train Accuracy: 0.9561, Validation Accuracy: 0.9570, Loss: 0.0405
# Epoch   8 Batch  176/269 - Train Accuracy: 0.9532, Validation Accuracy: 0.9612, Loss: 0.0428
# Epoch   8 Batch  184/269 - Train Accuracy: 0.9601, Validation Accuracy: 0.9609, Loss: 0.0390
# Epoch   8 Batch  192/269 - Train Accuracy: 0.9706, Validation Accuracy: 0.9609, Loss: 0.0380
# Epoch   8 Batch  200/269 - Train Accuracy: 0.9711, Validation Accuracy: 0.9545, Loss: 0.0376
# Epoch   8 Batch  208/269 - Train Accuracy: 0.9602, Validation Accuracy: 0.9606, Loss: 0.0434
# Epoch   8 Batch  216/269 - Train Accuracy: 0.9488, Validation Accuracy: 0.9685, Loss: 0.0481
# Epoch   8 Batch  224/269 - Train Accuracy: 0.9573, Validation Accuracy: 0.9635, Loss: 0.0473
# Epoch   8 Batch  232/269 - Train Accuracy: 0.9547, Validation Accuracy: 0.9606, Loss: 0.0382
# Epoch   8 Batch  240/269 - Train Accuracy: 0.9595, Validation Accuracy: 0.9698, Loss: 0.0378
# Epoch   8 Batch  248/269 - Train Accuracy: 0.9629, Validation Accuracy: 0.9648, Loss: 0.0374
# Epoch   8 Batch  256/269 - Train Accuracy: 0.9638, Validation Accuracy: 0.9617, Loss: 0.0375
# Epoch   8 Batch  264/269 - Train Accuracy: 0.9513, Validation Accuracy: 0.9663, Loss: 0.0396
# Epoch   9 Batch    8/269 - Train Accuracy: 0.9594, Validation Accuracy: 0.9604, Loss: 0.0422
# Epoch   9 Batch   16/269 - Train Accuracy: 0.9593, Validation Accuracy: 0.9636, Loss: 0.0415
# Epoch   9 Batch   24/269 - Train Accuracy: 0.9575, Validation Accuracy: 0.9608, Loss: 0.0357
# Epoch   9 Batch   32/269 - Train Accuracy: 0.9634, Validation Accuracy: 0.9677, Loss: 0.0330
# Epoch   9 Batch   40/269 - Train Accuracy: 0.9519, Validation Accuracy: 0.9645, Loss: 0.0413
# Epoch   9 Batch   48/269 - Train Accuracy: 0.9613, Validation Accuracy: 0.9679, Loss: 0.0350
# Epoch   9 Batch   56/269 - Train Accuracy: 0.9552, Validation Accuracy: 0.9611, Loss: 0.0389
# Epoch   9 Batch   64/269 - Train Accuracy: 0.9607, Validation Accuracy: 0.9631, Loss: 0.0316
# Epoch   9 Batch   72/269 - Train Accuracy: 0.9480, Validation Accuracy: 0.9597, Loss: 0.0430
# Epoch   9 Batch   80/269 - Train Accuracy: 0.9574, Validation Accuracy: 0.9607, Loss: 0.0390
# Epoch   9 Batch   88/269 - Train Accuracy: 0.9492, Validation Accuracy: 0.9614, Loss: 0.0420
# Epoch   9 Batch   96/269 - Train Accuracy: 0.9601, Validation Accuracy: 0.9626, Loss: 0.0431
# Epoch   9 Batch  104/269 - Train Accuracy: 0.9599, Validation Accuracy: 0.9600, Loss: 0.0390
# Epoch   9 Batch  112/269 - Train Accuracy: 0.9572, Validation Accuracy: 0.9574, Loss: 0.0418
# Epoch   9 Batch  120/269 - Train Accuracy: 0.9458, Validation Accuracy: 0.9618, Loss: 0.0450
# Epoch   9 Batch  128/269 - Train Accuracy: 0.9568, Validation Accuracy: 0.9580, Loss: 0.0361
# Epoch   9 Batch  136/269 - Train Accuracy: 0.9518, Validation Accuracy: 0.9604, Loss: 0.0457
# Epoch   9 Batch  144/269 - Train Accuracy: 0.9658, Validation Accuracy: 0.9648, Loss: 0.0328
# Epoch   9 Batch  152/269 - Train Accuracy: 0.9568, Validation Accuracy: 0.9644, Loss: 0.0362
# Epoch   9 Batch  160/269 - Train Accuracy: 0.9554, Validation Accuracy: 0.9620, Loss: 0.0374
# Epoch   9 Batch  168/269 - Train Accuracy: 0.9632, Validation Accuracy: 0.9634, Loss: 0.0372
# Epoch   9 Batch  176/269 - Train Accuracy: 0.9499, Validation Accuracy: 0.9604, Loss: 0.0410
# Epoch   9 Batch  184/269 - Train Accuracy: 0.9640, Validation Accuracy: 0.9650, Loss: 0.0363
# Epoch   9 Batch  192/269 - Train Accuracy: 0.9681, Validation Accuracy: 0.9590, Loss: 0.0376
# Epoch   9 Batch  200/269 - Train Accuracy: 0.9685, Validation Accuracy: 0.9585, Loss: 0.0344
# Epoch   9 Batch  208/269 - Train Accuracy: 0.9569, Validation Accuracy: 0.9666, Loss: 0.0445
# Epoch   9 Batch  216/269 - Train Accuracy: 0.9475, Validation Accuracy: 0.9585, Loss: 0.0499
# Epoch   9 Batch  224/269 - Train Accuracy: 0.9523, Validation Accuracy: 0.9640, Loss: 0.0501
# Epoch   9 Batch  232/269 - Train Accuracy: 0.9620, Validation Accuracy: 0.9599, Loss: 0.0368
# Epoch   9 Batch  240/269 - Train Accuracy: 0.9679, Validation Accuracy: 0.9558, Loss: 0.0366
# Epoch   9 Batch  248/269 - Train Accuracy: 0.9648, Validation Accuracy: 0.9584, Loss: 0.0361
# Epoch   9 Batch  256/269 - Train Accuracy: 0.9593, Validation Accuracy: 0.9575, Loss: 0.0357
# Epoch   9 Batch  264/269 - Train Accuracy: 0.9533, Validation Accuracy: 0.9576, Loss: 0.0390
# Model Trained and Saved

# %% [markdown]
# ### Save Parameters
# Save the `batch_size` and `save_path` parameters for inference.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Save parameters for checkpoint
helper.save_params(save_path)

# %% [markdown]
# # Checkpoint

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import tensorflow as tf
import numpy as np
import helper
import problem_unittests as tests

_, (source_vocab_to_int, target_vocab_to_int), (source_int_to_vocab, target_int_to_vocab) = helper.load_preprocess()
load_path = helper.load_params()

# %% [markdown]
# ## Sentence to Sequence
# To feed a sentence into the model for translation, you first need to preprocess it.  Implement the function `sentence_to_seq()` to preprocess new sentences.
#
# - Convert the sentence to lowercase
# - Convert words into ids using `vocab_to_int`
#  - Convert words not in the vocabulary, to the `<UNK>` word id.

# %%
def sentence_to_seq(sentence, vocab_to_int):
    """
    Convert a sentence to a sequence of ids
    :param sentence: String
    :param vocab_to_int: Dictionary to go from the words to an id
    :return: List of word ids
    """
    # TODO: Implement Function
    return [vocab_to_int.get(word, vocab_to_int['<UNK>']) for word in sentence.lower().split()]


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_sentence_to_seq(sentence_to_seq)
# Out:
# Tests Passed

# %% [markdown]
# ## Translate
# This will translate `translate_sentence` from English to French.

# %%
translate_sentence = 'he saw a old yellow truck .'
#translate_sentence = 'I have a nice car .'

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
translate_sentence = sentence_to_seq(translate_sentence, source_vocab_to_int)

loaded_graph = tf.Graph()
with tf.Session(graph=loaded_graph) as sess:
    # Load saved model
    loader = tf.train.import_meta_graph(load_path + '.meta')
    loader.restore(sess, load_path)

    input_data = loaded_graph.get_tensor_by_name('input:0')
    logits = loaded_graph.get_tensor_by_name('predictions:0')
    target_sequence_length = loaded_graph.get_tensor_by_name('target_sequence_length:0')
    source_sequence_length = loaded_graph.get_tensor_by_name('source_sequence_length:0')
    keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')

    translate_logits = sess.run(logits, {input_data: [translate_sentence]*batch_size,
                                         target_sequence_length: [len(translate_sentence)*2]*batch_size,
                                         source_sequence_length: [len(translate_sentence)]*batch_size,
                                         keep_prob: 1.0})[0]

print('Input')
print('  Word Ids:      {}'.format([i for i in translate_sentence]))
print('  English Words: {}'.format([source_int_to_vocab[i] for i in translate_sentence]))

print('\nPrediction')
print('  Word Ids:      {}'.format([i for i in translate_logits]))
print('  French Words: {}'.format(" ".join([target_int_to_vocab[i] for i in translate_logits])))
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/dev
# Input
#   Word Ids:      [84, 141, 202, 42, 229, 157, 124]
#   English Words: ['he', 'saw', 'a', 'old', 'yellow', 'truck', '.']
#
# Prediction
#   Word Ids:      [349, 345, 241, 165, 123, 7, 4, 140, 1]
#   French Words: il a vu un vieux camion jaune . <EOS>

# %% [markdown]
# ## Imperfect Translation
# You might notice that some sentences translate better than others.  Since the dataset you're using only has a vocabulary of 227 English words of the thousands that you use, you're only going to see good results using these words.  For this project, you don't need a perfect translation. However, if you want to create a better translation model, you'll need better data.
#
# You can train on the [WMT10 French-English corpus](http://www.statmt.org/wmt10/training-giga-fren.tar).  This dataset has more vocabulary and richer in topics discussed.  However, this will take you days to train, so make sure you've a GPU and the neural network is performing well on dataset we provided.  Just make sure you play with the WMT10 corpus after you've submitted this project.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_language_translation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "helper.py" and "problem_unittests.py" files in your submission.
