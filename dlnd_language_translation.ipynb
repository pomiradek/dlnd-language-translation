# %% [markdown]
# # Language Translation
# In this project, you’re going to take a peek into the realm of neural network machine translation.  You’ll be training a sequence to sequence model on a dataset of English and French sentences that can translate new sentences from English to French.
# ## Get the Data
# Since translating the whole language of English to French will take lots of time to train, we have provided you with a small portion of the English corpus.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import helper
import problem_unittests as tests

source_path = 'data/small_vocab_en'
target_path = 'data/small_vocab_fr'
source_text = helper.load_data(source_path)
target_text = helper.load_data(target_path)

# %% [markdown]
# ## Explore the Data
# Play around with view_sentence_range to view different parts of the data.

# %%
view_sentence_range = (0, 10)

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np

print('Dataset Stats')
print('Roughly the number of unique words: {}'.format(len({word: None for word in source_text.split()})))

sentences = source_text.split('\n')
word_counts = [len(sentence.split()) for sentence in sentences]
print('Number of sentences: {}'.format(len(sentences)))
print('Average number of words in a sentence: {}'.format(np.average(word_counts)))

print()
print('English sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(source_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
print()
print('French sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(target_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
# Out:
# Dataset Stats
# Roughly the number of unique words: 227
# Number of sentences: 137861
# Average number of words in a sentence: 13.225277634719028
#
# English sentences 0 to 10:
# new jersey is sometimes quiet during autumn , and it is snowy in april .
# the united states is usually chilly during july , and it is usually freezing in november .
# california is usually quiet during march , and it is usually hot in june .
# the united states is sometimes mild during june , and it is cold in september .
# your least liked fruit is the grape , but my least liked is the apple .
# his favorite fruit is the orange , but my favorite is the grape .
# paris is relaxing during december , but it is usually chilly in july .
# new jersey is busy during spring , and it is never hot in march .
# our least liked fruit is the lemon , but my least liked is the grape .
# the united states is sometimes busy during january , and it is sometimes warm in november .
#
# French sentences 0 to 10:
# new jersey est parfois calme pendant l' automne , et il est neigeux en avril .
# les états-unis est généralement froid en juillet , et il gèle habituellement en novembre .
# california est généralement calme en mars , et il est généralement chaud en juin .
# les états-unis est parfois légère en juin , et il fait froid en septembre .
# votre moins aimé fruit est le raisin , mais mon moins aimé est la pomme .
# son fruit préféré est l'orange , mais mon préféré est le raisin .
# paris est relaxant en décembre , mais il est généralement froid en juillet .
# new jersey est occupé au printemps , et il est jamais chaude en mars .
# notre fruit est moins aimé le citron , mais mon moins aimé est le raisin .
# les états-unis est parfois occupé en janvier , et il est parfois chaud en novembre .

# %% [markdown]
# ## Implement Preprocessing Function
# ### Text to Word Ids
# As you did with other RNNs, you must turn the text into a number so the computer can understand it. In the function `text_to_ids()`, you'll turn `source_text` and `target_text` from words to ids.  However, you need to add the `<EOS>` word id at the end of `target_text`.  This will help the neural network predict when the sentence should end.
#
# You can get the `<EOS>` word id by doing:
# ```python
# target_vocab_to_int['<EOS>']
# ```
# You can get other word ids using `source_vocab_to_int` and `target_vocab_to_int`.

# %%
def text_to_ids(source_text, target_text, source_vocab_to_int, target_vocab_to_int):
    """
    Convert source and target text to proper word ids
    :param source_text: String that contains all the source text.
    :param target_text: String that contains all the target text.
    :param source_vocab_to_int: Dictionary to go from the source words to an id
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :return: A tuple of lists (source_id_text, target_id_text)
    """
    # TODO: Implement Function
    source_id_text = [[source_vocab_to_int[word] for word in line.split()] for line in source_text.split('\n')]
    target_id_text = [[target_vocab_to_int[word] for word in line.split()] + [target_vocab_to_int['<EOS>']] for line in target_text.split('\n')] 

    
    return (source_id_text, target_id_text)

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_text_to_ids(text_to_ids)
# Out:
# Tests Passed

# %% [markdown]
# ### Preprocess all the data and save it
# Running the code cell below will preprocess all the data and save it to file.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
helper.preprocess_and_save_data(source_path, target_path, text_to_ids)

# %% [markdown]
# # Check Point
# This is your first checkpoint. If you ever decide to come back to this notebook or have to restart the notebook, you can start from here. The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np
import helper
import problem_unittests as tests

(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = helper.load_preprocess()

# %% [markdown]
# ### Check the Version of TensorFlow and Access to GPU
# This will check to make sure you have the correct version of TensorFlow and access to a GPU

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
from distutils.version import LooseVersion
import warnings
import tensorflow as tf
from tensorflow.python.layers.core import Dense

# Check TensorFlow Version
assert LooseVersion(tf.__version__) >= LooseVersion('1.1'), 'Please use TensorFlow version 1.1 or newer'
print('TensorFlow Version: {}'.format(tf.__version__))

# Check for a GPU
if not tf.test.gpu_device_name():
    warnings.warn('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# Out:
# TensorFlow Version: 1.4.0
# Default GPU Device: /device:GPU:0

# %% [markdown]
# ## Build the Neural Network
# You'll build the components necessary to build a Sequence-to-Sequence model by implementing the following functions below:
# - `model_inputs`
# - `process_decoder_input`
# - `encoding_layer`
# - `decoding_layer_train`
# - `decoding_layer_infer`
# - `decoding_layer`
# - `seq2seq_model`
#
# ### Input
# Implement the `model_inputs()` function to create TF Placeholders for the Neural Network. It should create the following placeholders:
#
# - Input text placeholder named "input" using the TF Placeholder name parameter with rank 2.
# - Targets placeholder with rank 2.
# - Learning rate placeholder with rank 0.
# - Keep probability placeholder named "keep_prob" using the TF Placeholder name parameter with rank 0.
# - Target sequence length placeholder named "target_sequence_length" with rank 1
# - Max target sequence length tensor named "max_target_len" getting its value from applying tf.reduce_max on the target_sequence_length placeholder. Rank 0.
# - Source sequence length placeholder named "source_sequence_length" with rank 1
#
# Return the placeholders in the following the tuple (input, targets, learning rate, keep probability, target sequence length, max target sequence length, source sequence length)

# %%
def model_inputs():
    """
    Create TF Placeholders for input, targets, learning rate, and lengths of source and target sequences.
    :return: Tuple (input, targets, learning rate, keep probability, target sequence length,
    max target sequence length, source sequence length)
    """
    # TODO: Implement Function
    input = tf.placeholder(tf.int32, [None, None], name='input')
    targets = tf.placeholder(tf.int32, [None, None], name='targets')
    lr = tf.placeholder(tf.float32, name='learning_rate')
    keep_prob = tf.placeholder(tf.float32, name='keep_prob')

    target_sequence_length = tf.placeholder(tf.int32, (None,), name='target_sequence_length')
    max_target_sequence_length = tf.reduce_max(target_sequence_length, name='max_target_len')
    source_sequence_length = tf.placeholder(tf.int32, (None,), name='source_sequence_length')
    return (input, targets, lr, keep_prob, target_sequence_length, max_target_sequence_length, source_sequence_length)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_inputs(model_inputs)
# Out:
# Tests Passed

# %% [markdown]
# ### Process Decoder Input
# Implement `process_decoder_input` by removing the last word id from each batch in `target_data` and concat the GO ID to the begining of each batch.

# %%
def process_decoder_input(target_data, target_vocab_to_int, batch_size):
    """
    Preprocess target data for encoding
    :param target_data: Target Placehoder
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :param batch_size: Batch Size
    :return: Preprocessed target data
    """
    # TODO: Implement Function
    ending = tf.strided_slice(target_data, [0, 0], [batch_size, -1], [1, 1])
    dec_input = tf.concat([tf.fill([batch_size, 1], target_vocab_to_int['<GO>']), ending], 1)
    return dec_input

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_process_encoding_input(process_decoder_input)
# Out:
# Tests Passed

# %% [markdown]
# ### Encoding
# Implement `encoding_layer()` to create a Encoder RNN layer:
#  * Embed the encoder input using [`tf.contrib.layers.embed_sequence`](https://www.tensorflow.org/api_docs/python/tf/contrib/layers/embed_sequence)
#  * Construct a [stacked](https://github.com/tensorflow/tensorflow/blob/6947f65a374ebf29e74bb71e36fd82760056d82c/tensorflow/docs_src/tutorials/recurrent.md#stacking-multiple-lstms) [`tf.contrib.rnn.LSTMCell`](https://www.tensorflow.org/api_docs/python/tf/contrib/rnn/LSTMCell) wrapped in a [`tf.contrib.rnn.DropoutWrapper`](https://www.tensorflow.org/api_docs/python/tf/contrib/rnn/DropoutWrapper)
#  * Pass cell and embedded input to [`tf.nn.dynamic_rnn()`](https://www.tensorflow.org/api_docs/python/tf/nn/dynamic_rnn)

# %%
from imp import reload
reload(tests)

def encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob, 
                   source_sequence_length, source_vocab_size, 
                   encoding_embedding_size):
    """
    Create encoding layer
    :param rnn_inputs: Inputs for the RNN
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param keep_prob: Dropout keep probability
    :param source_sequence_length: a list of the lengths of each sequence in the batch
    :param source_vocab_size: vocabulary size of source data
    :param encoding_embedding_size: embedding size of source data
    :return: tuple (RNN output, RNN state)
    """
    # TODO: Implement Function
    # Encoder embedding
    enc_embed_input = tf.contrib.layers.embed_sequence(rnn_inputs, source_vocab_size, encoding_embedding_size)
    
     # RNN cell
    def make_cell(rnn_size, keep_prob):
        enc_cell = tf.contrib.rnn.LSTMCell(rnn_size,
                                           initializer=tf.random_uniform_initializer(-0.1, 0.1, seed=2))
        enc_cell = tf.contrib.rnn.DropoutWrapper(enc_cell, output_keep_prob=keep_prob)
        return enc_cell

    enc_cell = tf.contrib.rnn.MultiRNNCell([make_cell(rnn_size, keep_prob) for _ in range(num_layers)])
    
    rnn_output, rnn_state = tf.nn.dynamic_rnn(enc_cell, enc_embed_input, sequence_length=source_sequence_length, dtype=tf.float32)
    
    return (rnn_output, rnn_state)

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_encoding_layer(encoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### Decoding - Training
# Create a training decoding layer:
# * Create a [`tf.contrib.seq2seq.TrainingHelper`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/TrainingHelper)
# * Create a [`tf.contrib.seq2seq.BasicDecoder`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/BasicDecoder)
# * Obtain the decoder outputs from [`tf.contrib.seq2seq.dynamic_decode`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/dynamic_decode)

# %%
def decoding_layer_train(encoder_state, dec_cell, dec_embed_input, 
                         target_sequence_length, max_summary_length, 
                         output_layer, keep_prob):
    """
    Create a decoding layer for training
    :param encoder_state: Encoder State
    :param dec_cell: Decoder RNN Cell
    :param dec_embed_input: Decoder embedded input
    :param target_sequence_length: The lengths of each sequence in the target batch
    :param max_summary_length: The length of the longest sequence in the batch
    :param output_layer: Function to apply the output layer
    :param keep_prob: Dropout keep probability
    :return: BasicDecoderOutput containing training logits and sample_id
    """
    # TODO: Implement Function
    # Helper for the training process. Used by BasicDecoder to read inputs.
    training_helper = tf.contrib.seq2seq.TrainingHelper(inputs=dec_embed_input,
                                                        sequence_length=target_sequence_length,
                                                        time_major=False)


    # Basic decoder
    training_decoder = tf.contrib.seq2seq.BasicDecoder(dec_cell,
                                                       training_helper,
                                                       encoder_state,
                                                       output_layer) 

    # Perform dynamic decoding using the decoder
    training_decoder_output = tf.contrib.seq2seq.dynamic_decode(training_decoder,
                                                                   impute_finished=True,
                                                                   maximum_iterations=max_summary_length)[0]
    return training_decoder_output



"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer_train(decoding_layer_train)
# Out:
# Tests Passed

# %% [markdown]
# ### Decoding - Inference
# Create inference decoder:
# * Create a [`tf.contrib.seq2seq.GreedyEmbeddingHelper`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/GreedyEmbeddingHelper)
# * Create a [`tf.contrib.seq2seq.BasicDecoder`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/BasicDecoder)
# * Obtain the decoder outputs from [`tf.contrib.seq2seq.dynamic_decode`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/dynamic_decode)

# %%
def decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id,
                         end_of_sequence_id, max_target_sequence_length,
                         vocab_size, output_layer, batch_size, keep_prob):
    """
    Create a decoding layer for inference
    :param encoder_state: Encoder state
    :param dec_cell: Decoder RNN Cell
    :param dec_embeddings: Decoder embeddings
    :param start_of_sequence_id: GO ID
    :param end_of_sequence_id: EOS Id
    :param max_target_sequence_length: Maximum length of target sequences
    :param vocab_size: Size of decoder/target vocabulary
    :param decoding_scope: TenorFlow Variable Scope for decoding
    :param output_layer: Function to apply the output layer
    :param batch_size: Batch size
    :param keep_prob: Dropout keep probability
    :return: BasicDecoderOutput containing inference logits and sample_id
    """
    # TODO: Implement Function
    start_ids = tf.tile([start_of_sequence_id], [batch_size])

    # Helper for the inference process.
    inference_helper = tf.contrib.seq2seq.GreedyEmbeddingHelper(dec_embeddings,
                                                            start_ids,
                                                            target_vocab_to_int['<EOS>'])

    # Basic decoder
    inference_decoder = tf.contrib.seq2seq.BasicDecoder(dec_cell,
                                                    inference_helper,
                                                    encoder_state,
                                                    output_layer)

    # Perform dynamic decoding using the decoder
    inference_decoder_output = tf.contrib.seq2seq.dynamic_decode(inference_decoder,
                                                        impute_finished=True,
                                                        maximum_iterations=max_target_sequence_length)[0]
    return inference_decoder_output



"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer_infer(decoding_layer_infer)
# Out:
# Tests Passed

# %% [markdown]
# ### Build the Decoding Layer
# Implement `decoding_layer()` to create a Decoder RNN layer.
#
# * Embed the target sequences
# * Construct the decoder LSTM cell (just like you constructed the encoder cell above)
# * Create an output layer to map the outputs of the decoder to the elements of our vocabulary
# * Use the your `decoding_layer_train(encoder_state, dec_cell, dec_embed_input, target_sequence_length, max_target_sequence_length, output_layer, keep_prob)` function to get the training logits.
# * Use your `decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id, end_of_sequence_id, max_target_sequence_length, vocab_size, output_layer, batch_size, keep_prob)` function to get the inference logits.
#
# Note: You'll need to use [tf.variable_scope](https://www.tensorflow.org/api_docs/python/tf/variable_scope) to share variables between training and inference.

# %%
def decoding_layer(dec_input, encoder_state,
                   target_sequence_length, max_target_sequence_length,
                   rnn_size,
                   num_layers, target_vocab_to_int, target_vocab_size,
                   batch_size, keep_prob, decoding_embedding_size):
    """
    Create decoding layer
    :param dec_input: Decoder input
    :param encoder_state: Encoder state
    :param target_sequence_length: The lengths of each sequence in the target batch
    :param max_target_sequence_length: Maximum length of target sequences
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :param target_vocab_size: Size of target vocabulary
    :param batch_size: The size of the batch
    :param keep_prob: Dropout keep probability
    :param decoding_embedding_size: Decoding embedding size
    :return: Tuple of (Training BasicDecoderOutput, Inference BasicDecoderOutput)
    """
    # TODO: Implement Function
    # 1. Decoder Embedding
    dec_embeddings = tf.Variable(tf.random_uniform([target_vocab_size, decoding_embedding_size]))
    dec_embed_input = tf.nn.embedding_lookup(dec_embeddings, dec_input)

    # 2. Construct the decoder cell
    def make_cell(rnn_size, keep_prob):
        enc_cell = tf.contrib.rnn.LSTMCell(rnn_size,
                                           initializer=tf.random_uniform_initializer(-0.1, 0.1, seed=2))
        enc_cell = tf.contrib.rnn.DropoutWrapper(enc_cell, output_keep_prob=keep_prob)
        return enc_cell

    dec_cell = tf.contrib.rnn.MultiRNNCell([make_cell(rnn_size, keep_prob) for _ in range(num_layers)])
     
    # 3. Dense layer to translate the decoder's output at each time 
    # step into a choice from the target vocabulary
    with tf.variable_scope("decode"):
        output_layer = Dense(target_vocab_size,
                             kernel_initializer = tf.truncated_normal_initializer(mean = 0.0, stddev=0.1))

        training_decoder_output = decoding_layer_train(encoder_state, dec_cell, dec_embed_input, target_sequence_length, max_target_sequence_length, output_layer, keep_prob)
    
    with tf.variable_scope("decode", reuse=True):
        start_of_sequence_id = target_vocab_to_int['<GO>']
        end_of_sequence_id = target_vocab_to_int['<EOS>']

        inference_decoder_output = decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id, end_of_sequence_id, max_target_sequence_length, target_vocab_size, output_layer, batch_size, keep_prob)

    return training_decoder_output, inference_decoder_output


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer(decoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### Build the Neural Network
# Apply the functions you implemented above to:
#
# - Encode the input using your `encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob,  source_sequence_length, source_vocab_size, encoding_embedding_size)`.
# - Process target data using your `process_decoder_input(target_data, target_vocab_to_int, batch_size)` function.
# - Decode the encoded input using your `decoding_layer(dec_input, enc_state, target_sequence_length, max_target_sentence_length, rnn_size, num_layers, target_vocab_to_int, target_vocab_size, batch_size, keep_prob, dec_embedding_size)` function.

# %%
def seq2seq_model(input_data, target_data, keep_prob, batch_size,
                  source_sequence_length, target_sequence_length,
                  max_target_sentence_length,
                  source_vocab_size, target_vocab_size,
                  enc_embedding_size, dec_embedding_size,
                  rnn_size, num_layers, target_vocab_to_int):
    """
    Build the Sequence-to-Sequence part of the neural network
    :param input_data: Input placeholder
    :param target_data: Target placeholder
    :param keep_prob: Dropout keep probability placeholder
    :param batch_size: Batch Size
    :param source_sequence_length: Sequence Lengths of source sequences in the batch
    :param target_sequence_length: Sequence Lengths of target sequences in the batch
    :param source_vocab_size: Source vocabulary size
    :param target_vocab_size: Target vocabulary size
    :param enc_embedding_size: Decoder embedding size
    :param dec_embedding_size: Encoder embedding size
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :return: Tuple of (Training BasicDecoderOutput, Inference BasicDecoderOutput)
    """
    # TODO: Implement Function
    # Pass the input data through the encoder. We'll ignore the encoder output, but use the state
    _, enc_state = encoding_layer(input_data, rnn_size, num_layers, keep_prob, source_sequence_length, source_vocab_size, enc_embedding_size)
    
    # Prepare the target sequences we'll feed to the decoder in training mode
    dec_input = process_decoder_input(target_data, target_vocab_to_int, batch_size)
    
    # Pass encoder state and decoder inputs to the decoders
    training_decoder_output, inference_decoder_output = decoding_layer(dec_input, enc_state, target_sequence_length, max_target_sentence_length, rnn_size, num_layers, target_vocab_to_int, target_vocab_size, batch_size, keep_prob, dec_embedding_size)
    return training_decoder_output, inference_decoder_output


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_seq2seq_model(seq2seq_model)
# Out:
# Tests Passed

# %% [markdown]
# ## Neural Network Training
# ### Hyperparameters
# Tune the following parameters:
#
# - Set `epochs` to the number of epochs.
# - Set `batch_size` to the batch size.
# - Set `rnn_size` to the size of the RNNs.
# - Set `num_layers` to the number of layers.
# - Set `encoding_embedding_size` to the size of the embedding for the encoder.
# - Set `decoding_embedding_size` to the size of the embedding for the decoder.
# - Set `learning_rate` to the learning rate.
# - Set `keep_probability` to the Dropout keep probability
# - Set `display_step` to state how many steps between each debug output statement

# %%
# Number of Epochs
epochs = 10
# Batch Size
batch_size = 512
# RNN Size
rnn_size = 256
# Number of Layers
num_layers = 2
# Embedding Size
encoding_embedding_size = 128
decoding_embedding_size = 128
# Learning Rate
learning_rate = 0.01
# Dropout Keep Probability
keep_probability = 0.5
display_step = 8

# %% [markdown]
# ### Build the Graph
# Build the graph using the neural network you implemented.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_path = 'checkpoints/dev'
(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = helper.load_preprocess()
max_target_sentence_length = max([len(sentence) for sentence in source_int_text])

train_graph = tf.Graph()
with train_graph.as_default():
    input_data, targets, lr, keep_prob, target_sequence_length, max_target_sequence_length, source_sequence_length = model_inputs()

    #sequence_length = tf.placeholder_with_default(max_target_sentence_length, None, name='sequence_length')
    input_shape = tf.shape(input_data)

    train_logits, inference_logits = seq2seq_model(tf.reverse(input_data, [-1]),
                                                   targets,
                                                   keep_prob,
                                                   batch_size,
                                                   source_sequence_length,
                                                   target_sequence_length,
                                                   max_target_sequence_length,
                                                   len(source_vocab_to_int),
                                                   len(target_vocab_to_int),
                                                   encoding_embedding_size,
                                                   decoding_embedding_size,
                                                   rnn_size,
                                                   num_layers,
                                                   target_vocab_to_int)


    training_logits = tf.identity(train_logits.rnn_output, name='logits')
    inference_logits = tf.identity(inference_logits.sample_id, name='predictions')

    masks = tf.sequence_mask(target_sequence_length, max_target_sequence_length, dtype=tf.float32, name='masks')

    with tf.name_scope("optimization"):
        # Loss function
        cost = tf.contrib.seq2seq.sequence_loss(
            training_logits,
            targets,
            masks)

        # Optimizer
        optimizer = tf.train.AdamOptimizer(lr)

        # Gradient Clipping
        gradients = optimizer.compute_gradients(cost)
        capped_gradients = [(tf.clip_by_value(grad, -1., 1.), var) for grad, var in gradients if grad is not None]
        train_op = optimizer.apply_gradients(capped_gradients)

# %% [markdown]
# Batch and pad the source and target sequences

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
def pad_sentence_batch(sentence_batch, pad_int):
    """Pad sentences with <PAD> so that each sentence of a batch has the same length"""
    max_sentence = max([len(sentence) for sentence in sentence_batch])
    return [sentence + [pad_int] * (max_sentence - len(sentence)) for sentence in sentence_batch]


def get_batches(sources, targets, batch_size, source_pad_int, target_pad_int):
    """Batch targets, sources, and the lengths of their sentences together"""
    for batch_i in range(0, len(sources)//batch_size):
        start_i = batch_i * batch_size

        # Slice the right amount for the batch
        sources_batch = sources[start_i:start_i + batch_size]
        targets_batch = targets[start_i:start_i + batch_size]

        # Pad
        pad_sources_batch = np.array(pad_sentence_batch(sources_batch, source_pad_int))
        pad_targets_batch = np.array(pad_sentence_batch(targets_batch, target_pad_int))

        # Need the lengths for the _lengths parameters
        pad_targets_lengths = []
        for target in pad_targets_batch:
            pad_targets_lengths.append(len(target))

        pad_source_lengths = []
        for source in pad_sources_batch:
            pad_source_lengths.append(len(source))

        yield pad_sources_batch, pad_targets_batch, pad_source_lengths, pad_targets_lengths

# %% [markdown]
# ### Train
# Train the neural network on the preprocessed data. If you have a hard time getting a good loss, check the forms to see if anyone is having the same problem.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
def get_accuracy(target, logits):
    """
    Calculate accuracy
    """
    max_seq = max(target.shape[1], logits.shape[1])
    if max_seq - target.shape[1]:
        target = np.pad(
            target,
            [(0,0),(0,max_seq - target.shape[1])],
            'constant')
    if max_seq - logits.shape[1]:
        logits = np.pad(
            logits,
            [(0,0),(0,max_seq - logits.shape[1])],
            'constant')

    return np.mean(np.equal(target, logits))

# Split data to training and validation sets
train_source = source_int_text[batch_size:]
train_target = target_int_text[batch_size:]
valid_source = source_int_text[:batch_size]
valid_target = target_int_text[:batch_size]
(valid_sources_batch, valid_targets_batch, valid_sources_lengths, valid_targets_lengths ) = next(get_batches(valid_source,
                                                                                                             valid_target,
                                                                                                             batch_size,
                                                                                                             source_vocab_to_int['<PAD>'],
                                                                                                             target_vocab_to_int['<PAD>']))                                                                                                  
with tf.Session(graph=train_graph) as sess:
    sess.run(tf.global_variables_initializer())

    for epoch_i in range(epochs):
        for batch_i, (source_batch, target_batch, sources_lengths, targets_lengths) in enumerate(
                get_batches(train_source, train_target, batch_size,
                            source_vocab_to_int['<PAD>'],
                            target_vocab_to_int['<PAD>'])):

            _, loss = sess.run(
                [train_op, cost],
                {input_data: source_batch,
                 targets: target_batch,
                 lr: learning_rate,
                 target_sequence_length: targets_lengths,
                 source_sequence_length: sources_lengths,
                 keep_prob: keep_probability})


            if batch_i % display_step == 0 and batch_i > 0:


                batch_train_logits = sess.run(
                    inference_logits,
                    {input_data: source_batch,
                     source_sequence_length: sources_lengths,
                     target_sequence_length: targets_lengths,
                     keep_prob: 1.0})


                batch_valid_logits = sess.run(
                    inference_logits,
                    {input_data: valid_sources_batch,
                     source_sequence_length: valid_sources_lengths,
                     target_sequence_length: valid_targets_lengths,
                     keep_prob: 1.0})

                train_acc = get_accuracy(target_batch, batch_train_logits)

                valid_acc = get_accuracy(valid_targets_batch, batch_valid_logits)

                print('Epoch {:>3} Batch {:>4}/{} - Train Accuracy: {:>6.4f}, Validation Accuracy: {:>6.4f}, Loss: {:>6.4f}'
                      .format(epoch_i, batch_i, len(source_int_text) // batch_size, train_acc, valid_acc, loss))

    # Save Model
    saver = tf.train.Saver()
    saver.save(sess, save_path)
    print('Model Trained and Saved')
# Out:
# Epoch   0 Batch    8/269 - Train Accuracy: 0.2854, Validation Accuracy: 0.3501, Loss: 3.6105
# Epoch   0 Batch   16/269 - Train Accuracy: 0.3715, Validation Accuracy: 0.3995, Loss: 2.9322
# Epoch   0 Batch   24/269 - Train Accuracy: 0.3913, Validation Accuracy: 0.4486, Loss: 2.7786
# Epoch   0 Batch   32/269 - Train Accuracy: 0.4295, Validation Accuracy: 0.4568, Loss: 2.5105
# Epoch   0 Batch   40/269 - Train Accuracy: 0.4427, Validation Accuracy: 0.4900, Loss: 2.4422
# Epoch   0 Batch   48/269 - Train Accuracy: 0.4873, Validation Accuracy: 0.5044, Loss: 2.1147
# Epoch   0 Batch   56/269 - Train Accuracy: 0.4966, Validation Accuracy: 0.5138, Loss: 2.0032
# Epoch   0 Batch   64/269 - Train Accuracy: 0.5346, Validation Accuracy: 0.5573, Loss: 1.8610
# Epoch   0 Batch   72/269 - Train Accuracy: 0.5726, Validation Accuracy: 0.5769, Loss: 1.6702
# Epoch   0 Batch   80/269 - Train Accuracy: 0.5762, Validation Accuracy: 0.5782, Loss: 1.5747
# Epoch   0 Batch   88/269 - Train Accuracy: 0.5535, Validation Accuracy: 0.5740, Loss: 1.4758
# Epoch   0 Batch   96/269 - Train Accuracy: 0.5607, Validation Accuracy: 0.5854, Loss: 1.3407
# Epoch   0 Batch  104/269 - Train Accuracy: 0.5725, Validation Accuracy: 0.5935, Loss: 1.2530
# Epoch   0 Batch  112/269 - Train Accuracy: 0.5911, Validation Accuracy: 0.5928, Loss: 1.1460
# Epoch   0 Batch  120/269 - Train Accuracy: 0.5812, Validation Accuracy: 0.5938, Loss: 1.1044
# Epoch   0 Batch  128/269 - Train Accuracy: 0.6341, Validation Accuracy: 0.6265, Loss: 0.9947
# Epoch   0 Batch  136/269 - Train Accuracy: 0.5764, Validation Accuracy: 0.6187, Loss: 1.0157
# Epoch   0 Batch  144/269 - Train Accuracy: 0.6044, Validation Accuracy: 0.6285, Loss: 0.8737
# Epoch   0 Batch  152/269 - Train Accuracy: 0.6234, Validation Accuracy: 0.6374, Loss: 0.8627
# Epoch   0 Batch  160/269 - Train Accuracy: 0.6180, Validation Accuracy: 0.6334, Loss: 0.8310
# Epoch   0 Batch  168/269 - Train Accuracy: 0.6310, Validation Accuracy: 0.6533, Loss: 0.8000
# Epoch   0 Batch  176/269 - Train Accuracy: 0.6354, Validation Accuracy: 0.6704, Loss: 0.7957
# Epoch   0 Batch  184/269 - Train Accuracy: 0.6418, Validation Accuracy: 0.6641, Loss: 0.7484
# Epoch   0 Batch  192/269 - Train Accuracy: 0.6555, Validation Accuracy: 0.6606, Loss: 0.7049
# Epoch   0 Batch  200/269 - Train Accuracy: 0.6528, Validation Accuracy: 0.6708, Loss: 0.7031
# Epoch   0 Batch  208/269 - Train Accuracy: 0.6620, Validation Accuracy: 0.6735, Loss: 0.6917
# Epoch   0 Batch  216/269 - Train Accuracy: 0.6427, Validation Accuracy: 0.6845, Loss: 0.6765
# Epoch   0 Batch  224/269 - Train Accuracy: 0.6842, Validation Accuracy: 0.6923, Loss: 0.6413
# Epoch   0 Batch  232/269 - Train Accuracy: 0.6549, Validation Accuracy: 0.6938, Loss: 0.6403
# Epoch   0 Batch  240/269 - Train Accuracy: 0.7112, Validation Accuracy: 0.6921, Loss: 0.5400
# Epoch   0 Batch  248/269 - Train Accuracy: 0.6887, Validation Accuracy: 0.6898, Loss: 0.5678
# Epoch   0 Batch  256/269 - Train Accuracy: 0.6743, Validation Accuracy: 0.6934, Loss: 0.5657
# Epoch   0 Batch  264/269 - Train Accuracy: 0.6881, Validation Accuracy: 0.7049, Loss: 0.5823
# Epoch   1 Batch    8/269 - Train Accuracy: 0.6811, Validation Accuracy: 0.7061, Loss: 0.5602
# Epoch   1 Batch   16/269 - Train Accuracy: 0.7080, Validation Accuracy: 0.7231, Loss: 0.5181
# Epoch   1 Batch   24/269 - Train Accuracy: 0.7112, Validation Accuracy: 0.7300, Loss: 0.5312
# Epoch   1 Batch   32/269 - Train Accuracy: 0.7308, Validation Accuracy: 0.7363, Loss: 0.4930
# Epoch   1 Batch   40/269 - Train Accuracy: 0.7139, Validation Accuracy: 0.7286, Loss: 0.5096
# Epoch   1 Batch   48/269 - Train Accuracy: 0.7236, Validation Accuracy: 0.7296, Loss: 0.4593
# Epoch   1 Batch   56/269 - Train Accuracy: 0.7274, Validation Accuracy: 0.7431, Loss: 0.4661
# Epoch   1 Batch   64/269 - Train Accuracy: 0.7498, Validation Accuracy: 0.7480, Loss: 0.4296
# Epoch   1 Batch   72/269 - Train Accuracy: 0.7461, Validation Accuracy: 0.7467, Loss: 0.4367
# Epoch   1 Batch   80/269 - Train Accuracy: 0.7486, Validation Accuracy: 0.7545, Loss: 0.4212
# Epoch   1 Batch   88/269 - Train Accuracy: 0.7461, Validation Accuracy: 0.7609, Loss: 0.4202
# Epoch   1 Batch   96/269 - Train Accuracy: 0.7534, Validation Accuracy: 0.7702, Loss: 0.4045
# Epoch   1 Batch  104/269 - Train Accuracy: 0.7708, Validation Accuracy: 0.7588, Loss: 0.3968
# Epoch   1 Batch  112/269 - Train Accuracy: 0.7719, Validation Accuracy: 0.7723, Loss: 0.3873
# Epoch   1 Batch  120/269 - Train Accuracy: 0.7896, Validation Accuracy: 0.7811, Loss: 0.3869
# Epoch   1 Batch  128/269 - Train Accuracy: 0.7909, Validation Accuracy: 0.7778, Loss: 0.3674
# Epoch   1 Batch  136/269 - Train Accuracy: 0.7729, Validation Accuracy: 0.7965, Loss: 0.3831
# Epoch   1 Batch  144/269 - Train Accuracy: 0.7993, Validation Accuracy: 0.8036, Loss: 0.3291
# Epoch   1 Batch  152/269 - Train Accuracy: 0.8024, Validation Accuracy: 0.8042, Loss: 0.3422
# Epoch   1 Batch  160/269 - Train Accuracy: 0.8170, Validation Accuracy: 0.8078, Loss: 0.3352
# Epoch   1 Batch  168/269 - Train Accuracy: 0.8111, Validation Accuracy: 0.8157, Loss: 0.3318
# Epoch   1 Batch  176/269 - Train Accuracy: 0.8175, Validation Accuracy: 0.8271, Loss: 0.3312
# Epoch   1 Batch  184/269 - Train Accuracy: 0.8433, Validation Accuracy: 0.8250, Loss: 0.3210
# Epoch   1 Batch  192/269 - Train Accuracy: 0.8514, Validation Accuracy: 0.8298, Loss: 0.2960
# Epoch   1 Batch  200/269 - Train Accuracy: 0.8301, Validation Accuracy: 0.8335, Loss: 0.2958
# Epoch   1 Batch  208/269 - Train Accuracy: 0.8457, Validation Accuracy: 0.8390, Loss: 0.2903
# Epoch   1 Batch  216/269 - Train Accuracy: 0.8371, Validation Accuracy: 0.8487, Loss: 0.2963
# Epoch   1 Batch  224/269 - Train Accuracy: 0.8400, Validation Accuracy: 0.8553, Loss: 0.2772
# Epoch   1 Batch  232/269 - Train Accuracy: 0.8538, Validation Accuracy: 0.8604, Loss: 0.2659
# Epoch   1 Batch  240/269 - Train Accuracy: 0.8659, Validation Accuracy: 0.8551, Loss: 0.2333
# Epoch   1 Batch  248/269 - Train Accuracy: 0.8745, Validation Accuracy: 0.8692, Loss: 0.2385
# Epoch   1 Batch  256/269 - Train Accuracy: 0.8454, Validation Accuracy: 0.8550, Loss: 0.2344
# Epoch   1 Batch  264/269 - Train Accuracy: 0.8347, Validation Accuracy: 0.8740, Loss: 0.2509
# Epoch   2 Batch    8/269 - Train Accuracy: 0.8766, Validation Accuracy: 0.8784, Loss: 0.2304
# Epoch   2 Batch   16/269 - Train Accuracy: 0.8742, Validation Accuracy: 0.8825, Loss: 0.2151
# Epoch   2 Batch   24/269 - Train Accuracy: 0.8691, Validation Accuracy: 0.8844, Loss: 0.2099
# Epoch   2 Batch   32/269 - Train Accuracy: 0.8864, Validation Accuracy: 0.8845, Loss: 0.1916
# Epoch   2 Batch   40/269 - Train Accuracy: 0.8772, Validation Accuracy: 0.8936, Loss: 0.1953
# Epoch   2 Batch   48/269 - Train Accuracy: 0.8963, Validation Accuracy: 0.8994, Loss: 0.1749
# Epoch   2 Batch   56/269 - Train Accuracy: 0.8933, Validation Accuracy: 0.8946, Loss: 0.1790
# Epoch   2 Batch   64/269 - Train Accuracy: 0.9055, Validation Accuracy: 0.9041, Loss: 0.1608
# Epoch   2 Batch   72/269 - Train Accuracy: 0.8920, Validation Accuracy: 0.9016, Loss: 0.1702
# Epoch   2 Batch   80/269 - Train Accuracy: 0.8982, Validation Accuracy: 0.9049, Loss: 0.1622
# Epoch   2 Batch   88/269 - Train Accuracy: 0.8818, Validation Accuracy: 0.8983, Loss: 0.1630
# Epoch   2 Batch   96/269 - Train Accuracy: 0.8748, Validation Accuracy: 0.8980, Loss: 0.1566
# Epoch   2 Batch  104/269 - Train Accuracy: 0.9089, Validation Accuracy: 0.9053, Loss: 0.1430
# Epoch   2 Batch  112/269 - Train Accuracy: 0.9100, Validation Accuracy: 0.9057, Loss: 0.1523
# Epoch   2 Batch  120/269 - Train Accuracy: 0.9031, Validation Accuracy: 0.9116, Loss: 0.1521
# Epoch   2 Batch  128/269 - Train Accuracy: 0.9133, Validation Accuracy: 0.9068, Loss: 0.1338
# Epoch   2 Batch  136/269 - Train Accuracy: 0.8899, Validation Accuracy: 0.9083, Loss: 0.1474
# Epoch   2 Batch  144/269 - Train Accuracy: 0.9169, Validation Accuracy: 0.9054, Loss: 0.1202
# Epoch   2 Batch  152/269 - Train Accuracy: 0.9208, Validation Accuracy: 0.9199, Loss: 0.1284
# Epoch   2 Batch  160/269 - Train Accuracy: 0.9103, Validation Accuracy: 0.9244, Loss: 0.1209
# Epoch   2 Batch  168/269 - Train Accuracy: 0.9168, Validation Accuracy: 0.9274, Loss: 0.1319
# Epoch   2 Batch  176/269 - Train Accuracy: 0.8997, Validation Accuracy: 0.9248, Loss: 0.1240
# Epoch   2 Batch  184/269 - Train Accuracy: 0.9294, Validation Accuracy: 0.9291, Loss: 0.1094
# Epoch   2 Batch  192/269 - Train Accuracy: 0.9329, Validation Accuracy: 0.9267, Loss: 0.1167
# Epoch   2 Batch  200/269 - Train Accuracy: 0.9166, Validation Accuracy: 0.9239, Loss: 0.1111
# Epoch   2 Batch  208/269 - Train Accuracy: 0.9252, Validation Accuracy: 0.9225, Loss: 0.1159
# Epoch   2 Batch  216/269 - Train Accuracy: 0.9199, Validation Accuracy: 0.9202, Loss: 0.1202
# Epoch   2 Batch  224/269 - Train Accuracy: 0.9230, Validation Accuracy: 0.9304, Loss: 0.1287
# Epoch   2 Batch  232/269 - Train Accuracy: 0.9239, Validation Accuracy: 0.9387, Loss: 0.1025
# Epoch   2 Batch  240/269 - Train Accuracy: 0.9315, Validation Accuracy: 0.9263, Loss: 0.0933
# Epoch   2 Batch  248/269 - Train Accuracy: 0.9288, Validation Accuracy: 0.9274, Loss: 0.0936
# Epoch   2 Batch  256/269 - Train Accuracy: 0.9121, Validation Accuracy: 0.9351, Loss: 0.0948
# Epoch   2 Batch  264/269 - Train Accuracy: 0.9157, Validation Accuracy: 0.9332, Loss: 0.1051
# Epoch   3 Batch    8/269 - Train Accuracy: 0.9344, Validation Accuracy: 0.9329, Loss: 0.1000
# Epoch   3 Batch   16/269 - Train Accuracy: 0.9183, Validation Accuracy: 0.9303, Loss: 0.1006
# Epoch   3 Batch   24/269 - Train Accuracy: 0.9261, Validation Accuracy: 0.9314, Loss: 0.0943
# Epoch   3 Batch   32/269 - Train Accuracy: 0.9317, Validation Accuracy: 0.9286, Loss: 0.0818
# Epoch   3 Batch   40/269 - Train Accuracy: 0.9241, Validation Accuracy: 0.9412, Loss: 0.0931
# Epoch   3 Batch   48/269 - Train Accuracy: 0.9399, Validation Accuracy: 0.9380, Loss: 0.0856
# Epoch   3 Batch   56/269 - Train Accuracy: 0.9366, Validation Accuracy: 0.9371, Loss: 0.0861
# Epoch   3 Batch   64/269 - Train Accuracy: 0.9262, Validation Accuracy: 0.9449, Loss: 0.0789
# Epoch   3 Batch   72/269 - Train Accuracy: 0.9289, Validation Accuracy: 0.9356, Loss: 0.0871
# Epoch   3 Batch   80/269 - Train Accuracy: 0.9263, Validation Accuracy: 0.9386, Loss: 0.0810
# Epoch   3 Batch   88/269 - Train Accuracy: 0.9128, Validation Accuracy: 0.9391, Loss: 0.0865
# Epoch   3 Batch   96/269 - Train Accuracy: 0.9276, Validation Accuracy: 0.9457, Loss: 0.0836
# Epoch   3 Batch  104/269 - Train Accuracy: 0.9431, Validation Accuracy: 0.9402, Loss: 0.0747
# Epoch   3 Batch  112/269 - Train Accuracy: 0.9376, Validation Accuracy: 0.9347, Loss: 0.0830
# Epoch   3 Batch  120/269 - Train Accuracy: 0.9359, Validation Accuracy: 0.9410, Loss: 0.0827
# Epoch   3 Batch  128/269 - Train Accuracy: 0.9449, Validation Accuracy: 0.9436, Loss: 0.0756
# Epoch   3 Batch  136/269 - Train Accuracy: 0.9286, Validation Accuracy: 0.9445, Loss: 0.0839
# Epoch   3 Batch  144/269 - Train Accuracy: 0.9474, Validation Accuracy: 0.9408, Loss: 0.0622
# Epoch   3 Batch  152/269 - Train Accuracy: 0.9528, Validation Accuracy: 0.9492, Loss: 0.0687
# Epoch   3 Batch  160/269 - Train Accuracy: 0.9395, Validation Accuracy: 0.9465, Loss: 0.0709
# Epoch   3 Batch  168/269 - Train Accuracy: 0.9486, Validation Accuracy: 0.9480, Loss: 0.0732
# Epoch   3 Batch  176/269 - Train Accuracy: 0.9177, Validation Accuracy: 0.9418, Loss: 0.0740
# Epoch   3 Batch  184/269 - Train Accuracy: 0.9487, Validation Accuracy: 0.9513, Loss: 0.0669
# Epoch   3 Batch  192/269 - Train Accuracy: 0.9547, Validation Accuracy: 0.9486, Loss: 0.0680
# Epoch   3 Batch  200/269 - Train Accuracy: 0.9540, Validation Accuracy: 0.9498, Loss: 0.0609
# Epoch   3 Batch  208/269 - Train Accuracy: 0.9543, Validation Accuracy: 0.9506, Loss: 0.0670
# Epoch   3 Batch  216/269 - Train Accuracy: 0.9313, Validation Accuracy: 0.9440, Loss: 0.0807
# Epoch   3 Batch  224/269 - Train Accuracy: 0.9434, Validation Accuracy: 0.9587, Loss: 0.0762
# Epoch   3 Batch  232/269 - Train Accuracy: 0.9497, Validation Accuracy: 0.9599, Loss: 0.0644
# Epoch   3 Batch  240/269 - Train Accuracy: 0.9465, Validation Accuracy: 0.9490, Loss: 0.0565
# Epoch   3 Batch  248/269 - Train Accuracy: 0.9592, Validation Accuracy: 0.9588, Loss: 0.0566
# Epoch   3 Batch  256/269 - Train Accuracy: 0.9355, Validation Accuracy: 0.9472, Loss: 0.0611
# Epoch   3 Batch  264/269 - Train Accuracy: 0.9316, Validation Accuracy: 0.9445, Loss: 0.0655
# Epoch   4 Batch    8/269 - Train Accuracy: 0.9535, Validation Accuracy: 0.9476, Loss: 0.0675
# Epoch   4 Batch   16/269 - Train Accuracy: 0.9310, Validation Accuracy: 0.9511, Loss: 0.0654
# Epoch   4 Batch   24/269 - Train Accuracy: 0.9465, Validation Accuracy: 0.9481, Loss: 0.0573
# Epoch   4 Batch   32/269 - Train Accuracy: 0.9508, Validation Accuracy: 0.9506, Loss: 0.0532
# Epoch   4 Batch   40/269 - Train Accuracy: 0.9376, Validation Accuracy: 0.9624, Loss: 0.0646
# Epoch   4 Batch   48/269 - Train Accuracy: 0.9561, Validation Accuracy: 0.9585, Loss: 0.0594
# Epoch   4 Batch   56/269 - Train Accuracy: 0.9506, Validation Accuracy: 0.9648, Loss: 0.0569
# Epoch   4 Batch   64/269 - Train Accuracy: 0.9546, Validation Accuracy: 0.9608, Loss: 0.0527
# Epoch   4 Batch   72/269 - Train Accuracy: 0.9488, Validation Accuracy: 0.9543, Loss: 0.0653
# Epoch   4 Batch   80/269 - Train Accuracy: 0.9513, Validation Accuracy: 0.9562, Loss: 0.0573
# Epoch   4 Batch   88/269 - Train Accuracy: 0.9379, Validation Accuracy: 0.9536, Loss: 0.0596
# Epoch   4 Batch   96/269 - Train Accuracy: 0.9501, Validation Accuracy: 0.9569, Loss: 0.0578
# Epoch   4 Batch  104/269 - Train Accuracy: 0.9518, Validation Accuracy: 0.9565, Loss: 0.0524
# Epoch   4 Batch  112/269 - Train Accuracy: 0.9466, Validation Accuracy: 0.9513, Loss: 0.0591
# Epoch   4 Batch  120/269 - Train Accuracy: 0.9530, Validation Accuracy: 0.9585, Loss: 0.0598
# Epoch   4 Batch  128/269 - Train Accuracy: 0.9649, Validation Accuracy: 0.9531, Loss: 0.0523
# Epoch   4 Batch  136/269 - Train Accuracy: 0.9397, Validation Accuracy: 0.9569, Loss: 0.0629
# Epoch   4 Batch  144/269 - Train Accuracy: 0.9582, Validation Accuracy: 0.9633, Loss: 0.0403
# Epoch   4 Batch  152/269 - Train Accuracy: 0.9606, Validation Accuracy: 0.9600, Loss: 0.0493
# Epoch   4 Batch  160/269 - Train Accuracy: 0.9588, Validation Accuracy: 0.9598, Loss: 0.0460
# Epoch   4 Batch  168/269 - Train Accuracy: 0.9574, Validation Accuracy: 0.9558, Loss: 0.0538
# Epoch   4 Batch  176/269 - Train Accuracy: 0.9441, Validation Accuracy: 0.9577, Loss: 0.0571
# Epoch   4 Batch  184/269 - Train Accuracy: 0.9576, Validation Accuracy: 0.9622, Loss: 0.0524
# Epoch   4 Batch  192/269 - Train Accuracy: 0.9682, Validation Accuracy: 0.9588, Loss: 0.0512
# Epoch   4 Batch  200/269 - Train Accuracy: 0.9593, Validation Accuracy: 0.9631, Loss: 0.0488
# Epoch   4 Batch  208/269 - Train Accuracy: 0.9617, Validation Accuracy: 0.9579, Loss: 0.0484
# Epoch   4 Batch  216/269 - Train Accuracy: 0.9570, Validation Accuracy: 0.9628, Loss: 0.0624
# Epoch   4 Batch  224/269 - Train Accuracy: 0.9581, Validation Accuracy: 0.9596, Loss: 0.0620
# Epoch   4 Batch  232/269 - Train Accuracy: 0.9529, Validation Accuracy: 0.9612, Loss: 0.0443
# Epoch   4 Batch  240/269 - Train Accuracy: 0.9583, Validation Accuracy: 0.9609, Loss: 0.0447
# Epoch   4 Batch  248/269 - Train Accuracy: 0.9627, Validation Accuracy: 0.9583, Loss: 0.0425
# Epoch   4 Batch  256/269 - Train Accuracy: 0.9559, Validation Accuracy: 0.9608, Loss: 0.0482
# Epoch   4 Batch  264/269 - Train Accuracy: 0.9444, Validation Accuracy: 0.9592, Loss: 0.0511
# Epoch   5 Batch    8/269 - Train Accuracy: 0.9611, Validation Accuracy: 0.9623, Loss: 0.0520
# Epoch   5 Batch   16/269 - Train Accuracy: 0.9538, Validation Accuracy: 0.9680, Loss: 0.0546
# Epoch   5 Batch   24/269 - Train Accuracy: 0.9566, Validation Accuracy: 0.9645, Loss: 0.0458
# Epoch   5 Batch   32/269 - Train Accuracy: 0.9683, Validation Accuracy: 0.9687, Loss: 0.0412
# Epoch   5 Batch   40/269 - Train Accuracy: 0.9523, Validation Accuracy: 0.9665, Loss: 0.0482
# Epoch   5 Batch   48/269 - Train Accuracy: 0.9681, Validation Accuracy: 0.9674, Loss: 0.0441
# Epoch   5 Batch   56/269 - Train Accuracy: 0.9592, Validation Accuracy: 0.9592, Loss: 0.0443
# Epoch   5 Batch   64/269 - Train Accuracy: 0.9661, Validation Accuracy: 0.9616, Loss: 0.0403
# Epoch   5 Batch   72/269 - Train Accuracy: 0.9553, Validation Accuracy: 0.9611, Loss: 0.0464
# Epoch   5 Batch   80/269 - Train Accuracy: 0.9619, Validation Accuracy: 0.9678, Loss: 0.0440
# Epoch   5 Batch   88/269 - Train Accuracy: 0.9587, Validation Accuracy: 0.9629, Loss: 0.0490
# Epoch   5 Batch   96/269 - Train Accuracy: 0.9525, Validation Accuracy: 0.9625, Loss: 0.0496
# Epoch   5 Batch  104/269 - Train Accuracy: 0.9687, Validation Accuracy: 0.9686, Loss: 0.0415
# Epoch   5 Batch  112/269 - Train Accuracy: 0.9513, Validation Accuracy: 0.9645, Loss: 0.0540
# Epoch   5 Batch  120/269 - Train Accuracy: 0.9581, Validation Accuracy: 0.9624, Loss: 0.0491
# Epoch   5 Batch  128/269 - Train Accuracy: 0.9664, Validation Accuracy: 0.9611, Loss: 0.0451
# Epoch   5 Batch  136/269 - Train Accuracy: 0.9413, Validation Accuracy: 0.9656, Loss: 0.0498
# Epoch   5 Batch  144/269 - Train Accuracy: 0.9747, Validation Accuracy: 0.9654, Loss: 0.0344
# Epoch   5 Batch  152/269 - Train Accuracy: 0.9659, Validation Accuracy: 0.9602, Loss: 0.0378
# Epoch   5 Batch  160/269 - Train Accuracy: 0.9634, Validation Accuracy: 0.9633, Loss: 0.0430
# Epoch   5 Batch  168/269 - Train Accuracy: 0.9632, Validation Accuracy: 0.9675, Loss: 0.0449
# Epoch   5 Batch  176/269 - Train Accuracy: 0.9570, Validation Accuracy: 0.9679, Loss: 0.0469
# Epoch   5 Batch  184/269 - Train Accuracy: 0.9613, Validation Accuracy: 0.9700, Loss: 0.0458
# Epoch   5 Batch  192/269 - Train Accuracy: 0.9645, Validation Accuracy: 0.9634, Loss: 0.0396
# Epoch   5 Batch  200/269 - Train Accuracy: 0.9705, Validation Accuracy: 0.9638, Loss: 0.0365
# Epoch   5 Batch  208/269 - Train Accuracy: 0.9626, Validation Accuracy: 0.9673, Loss: 0.0443
# Epoch   5 Batch  216/269 - Train Accuracy: 0.9552, Validation Accuracy: 0.9715, Loss: 0.0569
# Epoch   5 Batch  224/269 - Train Accuracy: 0.9578, Validation Accuracy: 0.9615, Loss: 0.0514
# Epoch   5 Batch  232/269 - Train Accuracy: 0.9559, Validation Accuracy: 0.9694, Loss: 0.0359
# Epoch   5 Batch  240/269 - Train Accuracy: 0.9634, Validation Accuracy: 0.9696, Loss: 0.0344
# Epoch   5 Batch  248/269 - Train Accuracy: 0.9698, Validation Accuracy: 0.9728, Loss: 0.0387
# Epoch   5 Batch  256/269 - Train Accuracy: 0.9586, Validation Accuracy: 0.9606, Loss: 0.0408
# Epoch   5 Batch  264/269 - Train Accuracy: 0.9504, Validation Accuracy: 0.9656, Loss: 0.0460
# Epoch   6 Batch    8/269 - Train Accuracy: 0.9691, Validation Accuracy: 0.9616, Loss: 0.0443
# Epoch   6 Batch   16/269 - Train Accuracy: 0.9532, Validation Accuracy: 0.9648, Loss: 0.0474
# Epoch   6 Batch   24/269 - Train Accuracy: 0.9657, Validation Accuracy: 0.9750, Loss: 0.0403
# Epoch   6 Batch   32/269 - Train Accuracy: 0.9759, Validation Accuracy: 0.9670, Loss: 0.0378
# Epoch   6 Batch   40/269 - Train Accuracy: 0.9612, Validation Accuracy: 0.9698, Loss: 0.0453
# Epoch   6 Batch   48/269 - Train Accuracy: 0.9623, Validation Accuracy: 0.9646, Loss: 0.0369
# Epoch   6 Batch   56/269 - Train Accuracy: 0.9565, Validation Accuracy: 0.9611, Loss: 0.0391
# Epoch   6 Batch   64/269 - Train Accuracy: 0.9618, Validation Accuracy: 0.9756, Loss: 0.0353
# Epoch   6 Batch   72/269 - Train Accuracy: 0.9600, Validation Accuracy: 0.9624, Loss: 0.0480
# Epoch   6 Batch   80/269 - Train Accuracy: 0.9576, Validation Accuracy: 0.9637, Loss: 0.0377
# Epoch   6 Batch   88/269 - Train Accuracy: 0.9607, Validation Accuracy: 0.9657, Loss: 0.0447
# Epoch   6 Batch   96/269 - Train Accuracy: 0.9558, Validation Accuracy: 0.9639, Loss: 0.0394
# Epoch   6 Batch  104/269 - Train Accuracy: 0.9661, Validation Accuracy: 0.9686, Loss: 0.0434
# Epoch   6 Batch  112/269 - Train Accuracy: 0.9595, Validation Accuracy: 0.9584, Loss: 0.0388
# Epoch   6 Batch  120/269 - Train Accuracy: 0.9675, Validation Accuracy: 0.9611, Loss: 0.0366
# Epoch   6 Batch  128/269 - Train Accuracy: 0.9719, Validation Accuracy: 0.9611, Loss: 0.0436
# Epoch   6 Batch  136/269 - Train Accuracy: 0.9491, Validation Accuracy: 0.9701, Loss: 0.0431
# Epoch   6 Batch  144/269 - Train Accuracy: 0.9724, Validation Accuracy: 0.9779, Loss: 0.0334
# Epoch   6 Batch  152/269 - Train Accuracy: 0.9708, Validation Accuracy: 0.9683, Loss: 0.0374
# Epoch   6 Batch  160/269 - Train Accuracy: 0.9683, Validation Accuracy: 0.9719, Loss: 0.0369
# Epoch   6 Batch  168/269 - Train Accuracy: 0.9669, Validation Accuracy: 0.9656, Loss: 0.0384
# Epoch   6 Batch  176/269 - Train Accuracy: 0.9648, Validation Accuracy: 0.9633, Loss: 0.0431
# Epoch   6 Batch  184/269 - Train Accuracy: 0.9658, Validation Accuracy: 0.9663, Loss: 0.0395
# Epoch   6 Batch  192/269 - Train Accuracy: 0.9758, Validation Accuracy: 0.9694, Loss: 0.0353
# Epoch   6 Batch  200/269 - Train Accuracy: 0.9771, Validation Accuracy: 0.9630, Loss: 0.0310
# Epoch   6 Batch  208/269 - Train Accuracy: 0.9730, Validation Accuracy: 0.9663, Loss: 0.0421
# Epoch   6 Batch  216/269 - Train Accuracy: 0.9665, Validation Accuracy: 0.9672, Loss: 0.0442
# Epoch   6 Batch  224/269 - Train Accuracy: 0.9621, Validation Accuracy: 0.9621, Loss: 0.0455
# Epoch   6 Batch  232/269 - Train Accuracy: 0.9618, Validation Accuracy: 0.9655, Loss: 0.0417
# Epoch   6 Batch  240/269 - Train Accuracy: 0.9642, Validation Accuracy: 0.9690, Loss: 0.0324
# Epoch   6 Batch  248/269 - Train Accuracy: 0.9646, Validation Accuracy: 0.9706, Loss: 0.0353
# Epoch   6 Batch  256/269 - Train Accuracy: 0.9626, Validation Accuracy: 0.9661, Loss: 0.0362
# Epoch   6 Batch  264/269 - Train Accuracy: 0.9616, Validation Accuracy: 0.9684, Loss: 0.0424
# Epoch   7 Batch    8/269 - Train Accuracy: 0.9773, Validation Accuracy: 0.9652, Loss: 0.0394
# Epoch   7 Batch   16/269 - Train Accuracy: 0.9617, Validation Accuracy: 0.9664, Loss: 0.0438
# Epoch   7 Batch   24/269 - Train Accuracy: 0.9535, Validation Accuracy: 0.9646, Loss: 0.0342
# Epoch   7 Batch   32/269 - Train Accuracy: 0.9708, Validation Accuracy: 0.9729, Loss: 0.0343
# Epoch   7 Batch   40/269 - Train Accuracy: 0.9623, Validation Accuracy: 0.9621, Loss: 0.0418
# Epoch   7 Batch   48/269 - Train Accuracy: 0.9743, Validation Accuracy: 0.9678, Loss: 0.0322
# Epoch   7 Batch   56/269 - Train Accuracy: 0.9668, Validation Accuracy: 0.9655, Loss: 0.0370
# Epoch   7 Batch   64/269 - Train Accuracy: 0.9658, Validation Accuracy: 0.9648, Loss: 0.0291
# Epoch   7 Batch   72/269 - Train Accuracy: 0.9674, Validation Accuracy: 0.9699, Loss: 0.0385
# Epoch   7 Batch   80/269 - Train Accuracy: 0.9708, Validation Accuracy: 0.9672, Loss: 0.0362
# Epoch   7 Batch   88/269 - Train Accuracy: 0.9611, Validation Accuracy: 0.9627, Loss: 0.0408
# Epoch   7 Batch   96/269 - Train Accuracy: 0.9662, Validation Accuracy: 0.9707, Loss: 0.0403
# Epoch   7 Batch  104/269 - Train Accuracy: 0.9682, Validation Accuracy: 0.9677, Loss: 0.0312
# Epoch   7 Batch  112/269 - Train Accuracy: 0.9643, Validation Accuracy: 0.9648, Loss: 0.0370
# Epoch   7 Batch  120/269 - Train Accuracy: 0.9646, Validation Accuracy: 0.9645, Loss: 0.0354
# Epoch   7 Batch  128/269 - Train Accuracy: 0.9724, Validation Accuracy: 0.9604, Loss: 0.0366
# Epoch   7 Batch  136/269 - Train Accuracy: 0.9546, Validation Accuracy: 0.9680, Loss: 0.0382
# Epoch   7 Batch  144/269 - Train Accuracy: 0.9789, Validation Accuracy: 0.9689, Loss: 0.0297
# Epoch   7 Batch  152/269 - Train Accuracy: 0.9713, Validation Accuracy: 0.9664, Loss: 0.0327
# Epoch   7 Batch  160/269 - Train Accuracy: 0.9743, Validation Accuracy: 0.9720, Loss: 0.0337
# Epoch   7 Batch  168/269 - Train Accuracy: 0.9634, Validation Accuracy: 0.9613, Loss: 0.0376
# Epoch   7 Batch  176/269 - Train Accuracy: 0.9646, Validation Accuracy: 0.9689, Loss: 0.0355
# Epoch   7 Batch  184/269 - Train Accuracy: 0.9587, Validation Accuracy: 0.9714, Loss: 0.0401
# Epoch   7 Batch  192/269 - Train Accuracy: 0.9701, Validation Accuracy: 0.9702, Loss: 0.0318
# Epoch   7 Batch  200/269 - Train Accuracy: 0.9729, Validation Accuracy: 0.9688, Loss: 0.0351
# Epoch   7 Batch  208/269 - Train Accuracy: 0.9673, Validation Accuracy: 0.9643, Loss: 0.0407
# Epoch   7 Batch  216/269 - Train Accuracy: 0.9463, Validation Accuracy: 0.9685, Loss: 0.0432
# Epoch   7 Batch  224/269 - Train Accuracy: 0.9633, Validation Accuracy: 0.9645, Loss: 0.0427
# Epoch   7 Batch  232/269 - Train Accuracy: 0.9701, Validation Accuracy: 0.9674, Loss: 0.0357
# Epoch   7 Batch  240/269 - Train Accuracy: 0.9672, Validation Accuracy: 0.9671, Loss: 0.0342
# Epoch   7 Batch  248/269 - Train Accuracy: 0.9663, Validation Accuracy: 0.9691, Loss: 0.0340
# Epoch   7 Batch  256/269 - Train Accuracy: 0.9652, Validation Accuracy: 0.9639, Loss: 0.0369
# Epoch   7 Batch  264/269 - Train Accuracy: 0.9595, Validation Accuracy: 0.9652, Loss: 0.0393
# Epoch   8 Batch    8/269 - Train Accuracy: 0.9688, Validation Accuracy: 0.9638, Loss: 0.0385
# Epoch   8 Batch   16/269 - Train Accuracy: 0.9685, Validation Accuracy: 0.9696, Loss: 0.0390
# Epoch   8 Batch   24/269 - Train Accuracy: 0.9625, Validation Accuracy: 0.9686, Loss: 0.0338
# Epoch   8 Batch   32/269 - Train Accuracy: 0.9750, Validation Accuracy: 0.9743, Loss: 0.0301
# Epoch   8 Batch   40/269 - Train Accuracy: 0.9632, Validation Accuracy: 0.9626, Loss: 0.0370
# Epoch   8 Batch   48/269 - Train Accuracy: 0.9696, Validation Accuracy: 0.9692, Loss: 0.0326
# Epoch   8 Batch   56/269 - Train Accuracy: 0.9652, Validation Accuracy: 0.9622, Loss: 0.0354
# Epoch   8 Batch   64/269 - Train Accuracy: 0.9601, Validation Accuracy: 0.9720, Loss: 0.0317
# Epoch   8 Batch   72/269 - Train Accuracy: 0.9632, Validation Accuracy: 0.9684, Loss: 0.0380
# Epoch   8 Batch   80/269 - Train Accuracy: 0.9683, Validation Accuracy: 0.9733, Loss: 0.0333
# Epoch   8 Batch   88/269 - Train Accuracy: 0.9600, Validation Accuracy: 0.9744, Loss: 0.0377
# Epoch   8 Batch   96/269 - Train Accuracy: 0.9651, Validation Accuracy: 0.9672, Loss: 0.0346
# Epoch   8 Batch  104/269 - Train Accuracy: 0.9726, Validation Accuracy: 0.9700, Loss: 0.0369
# Epoch   8 Batch  112/269 - Train Accuracy: 0.9621, Validation Accuracy: 0.9651, Loss: 0.0380
# Epoch   8 Batch  120/269 - Train Accuracy: 0.9732, Validation Accuracy: 0.9711, Loss: 0.0374
# Epoch   8 Batch  128/269 - Train Accuracy: 0.9726, Validation Accuracy: 0.9721, Loss: 0.0334
# Epoch   8 Batch  136/269 - Train Accuracy: 0.9539, Validation Accuracy: 0.9743, Loss: 0.0393
# Epoch   8 Batch  144/269 - Train Accuracy: 0.9734, Validation Accuracy: 0.9731, Loss: 0.0279
# Epoch   8 Batch  152/269 - Train Accuracy: 0.9753, Validation Accuracy: 0.9703, Loss: 0.0339
# Epoch   8 Batch  160/269 - Train Accuracy: 0.9725, Validation Accuracy: 0.9651, Loss: 0.0322
# Epoch   8 Batch  168/269 - Train Accuracy: 0.9691, Validation Accuracy: 0.9734, Loss: 0.0370
# Epoch   8 Batch  176/269 - Train Accuracy: 0.9676, Validation Accuracy: 0.9724, Loss: 0.0303
# Epoch   8 Batch  184/269 - Train Accuracy: 0.9691, Validation Accuracy: 0.9719, Loss: 0.0324
# Epoch   8 Batch  192/269 - Train Accuracy: 0.9738, Validation Accuracy: 0.9644, Loss: 0.0357
# Epoch   8 Batch  200/269 - Train Accuracy: 0.9781, Validation Accuracy: 0.9689, Loss: 0.0301
# Epoch   8 Batch  208/269 - Train Accuracy: 0.9719, Validation Accuracy: 0.9725, Loss: 0.0372
# Epoch   8 Batch  216/269 - Train Accuracy: 0.9687, Validation Accuracy: 0.9714, Loss: 0.0453
# Epoch   8 Batch  224/269 - Train Accuracy: 0.9651, Validation Accuracy: 0.9697, Loss: 0.0442
# Epoch   8 Batch  232/269 - Train Accuracy: 0.9688, Validation Accuracy: 0.9717, Loss: 0.0317
# Epoch   8 Batch  240/269 - Train Accuracy: 0.9705, Validation Accuracy: 0.9719, Loss: 0.0326
# Epoch   8 Batch  248/269 - Train Accuracy: 0.9741, Validation Accuracy: 0.9743, Loss: 0.0331
# Epoch   8 Batch  256/269 - Train Accuracy: 0.9713, Validation Accuracy: 0.9724, Loss: 0.0318
# Epoch   8 Batch  264/269 - Train Accuracy: 0.9699, Validation Accuracy: 0.9713, Loss: 0.0374
# Epoch   9 Batch    8/269 - Train Accuracy: 0.9742, Validation Accuracy: 0.9682, Loss: 0.0325
# Epoch   9 Batch   16/269 - Train Accuracy: 0.9654, Validation Accuracy: 0.9634, Loss: 0.0382
# Epoch   9 Batch   24/269 - Train Accuracy: 0.9700, Validation Accuracy: 0.9650, Loss: 0.0330
# Epoch   9 Batch   32/269 - Train Accuracy: 0.9736, Validation Accuracy: 0.9705, Loss: 0.0268
# Epoch   9 Batch   40/269 - Train Accuracy: 0.9680, Validation Accuracy: 0.9696, Loss: 0.0340
# Epoch   9 Batch   48/269 - Train Accuracy: 0.9708, Validation Accuracy: 0.9701, Loss: 0.0309
# Epoch   9 Batch   56/269 - Train Accuracy: 0.9656, Validation Accuracy: 0.9696, Loss: 0.0382
# Epoch   9 Batch   64/269 - Train Accuracy: 0.9704, Validation Accuracy: 0.9751, Loss: 0.0314
# Epoch   9 Batch   72/269 - Train Accuracy: 0.9687, Validation Accuracy: 0.9745, Loss: 0.0402
# Epoch   9 Batch   80/269 - Train Accuracy: 0.9616, Validation Accuracy: 0.9657, Loss: 0.0352
# Epoch   9 Batch   88/269 - Train Accuracy: 0.9635, Validation Accuracy: 0.9557, Loss: 0.0360
# Epoch   9 Batch   96/269 - Train Accuracy: 0.9654, Validation Accuracy: 0.9690, Loss: 0.0360
# Epoch   9 Batch  104/269 - Train Accuracy: 0.9770, Validation Accuracy: 0.9724, Loss: 0.0330
# Epoch   9 Batch  112/269 - Train Accuracy: 0.9584, Validation Accuracy: 0.9654, Loss: 0.0359
# Epoch   9 Batch  120/269 - Train Accuracy: 0.9678, Validation Accuracy: 0.9724, Loss: 0.0320
# Epoch   9 Batch  128/269 - Train Accuracy: 0.9781, Validation Accuracy: 0.9703, Loss: 0.0318
# Epoch   9 Batch  136/269 - Train Accuracy: 0.9574, Validation Accuracy: 0.9688, Loss: 0.0380
# Epoch   9 Batch  144/269 - Train Accuracy: 0.9786, Validation Accuracy: 0.9711, Loss: 0.0291
# Epoch   9 Batch  152/269 - Train Accuracy: 0.9759, Validation Accuracy: 0.9722, Loss: 0.0306
# Epoch   9 Batch  160/269 - Train Accuracy: 0.9699, Validation Accuracy: 0.9703, Loss: 0.0306
# Epoch   9 Batch  168/269 - Train Accuracy: 0.9755, Validation Accuracy: 0.9701, Loss: 0.0349
# Epoch   9 Batch  176/269 - Train Accuracy: 0.9682, Validation Accuracy: 0.9682, Loss: 0.0349
# Epoch   9 Batch  184/269 - Train Accuracy: 0.9665, Validation Accuracy: 0.9701, Loss: 0.0332
# Epoch   9 Batch  192/269 - Train Accuracy: 0.9792, Validation Accuracy: 0.9731, Loss: 0.0288
# Epoch   9 Batch  200/269 - Train Accuracy: 0.9753, Validation Accuracy: 0.9718, Loss: 0.0301
# Epoch   9 Batch  208/269 - Train Accuracy: 0.9702, Validation Accuracy: 0.9703, Loss: 0.0360
# Epoch   9 Batch  216/269 - Train Accuracy: 0.9605, Validation Accuracy: 0.9722, Loss: 0.0410
# Epoch   9 Batch  224/269 - Train Accuracy: 0.9651, Validation Accuracy: 0.9767, Loss: 0.0388
# Epoch   9 Batch  232/269 - Train Accuracy: 0.9694, Validation Accuracy: 0.9786, Loss: 0.0296
# Epoch   9 Batch  240/269 - Train Accuracy: 0.9691, Validation Accuracy: 0.9735, Loss: 0.0330
# Epoch   9 Batch  248/269 - Train Accuracy: 0.9739, Validation Accuracy: 0.9707, Loss: 0.0306
# Epoch   9 Batch  256/269 - Train Accuracy: 0.9665, Validation Accuracy: 0.9670, Loss: 0.0332
# Epoch   9 Batch  264/269 - Train Accuracy: 0.9609, Validation Accuracy: 0.9689, Loss: 0.0364
# Model Trained and Saved

# %% [markdown]
# ### Save Parameters
# Save the `batch_size` and `save_path` parameters for inference.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Save parameters for checkpoint
helper.save_params(save_path)

# %% [markdown]
# # Checkpoint

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import tensorflow as tf
import numpy as np
import helper
import problem_unittests as tests

_, (source_vocab_to_int, target_vocab_to_int), (source_int_to_vocab, target_int_to_vocab) = helper.load_preprocess()
load_path = helper.load_params()

# %% [markdown]
# ## Sentence to Sequence
# To feed a sentence into the model for translation, you first need to preprocess it.  Implement the function `sentence_to_seq()` to preprocess new sentences.
#
# - Convert the sentence to lowercase
# - Convert words into ids using `vocab_to_int`
#  - Convert words not in the vocabulary, to the `<UNK>` word id.

# %%
def sentence_to_seq(sentence, vocab_to_int):
    """
    Convert a sentence to a sequence of ids
    :param sentence: String
    :param vocab_to_int: Dictionary to go from the words to an id
    :return: List of word ids
    """
    # TODO: Implement Function
    return [vocab_to_int.get(word, vocab_to_int['<UNK>']) for word in sentence.lower().split()]


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_sentence_to_seq(sentence_to_seq)
# Out:
# Tests Passed

# %% [markdown]
# ## Translate
# This will translate `translate_sentence` from English to French.

# %%
translate_sentence = 'he saw a old yellow truck .'
#translate_sentence = 'I have a nice car .'

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
translate_sentence = sentence_to_seq(translate_sentence, source_vocab_to_int)

loaded_graph = tf.Graph()
with tf.Session(graph=loaded_graph) as sess:
    # Load saved model
    loader = tf.train.import_meta_graph(load_path + '.meta')
    loader.restore(sess, load_path)

    input_data = loaded_graph.get_tensor_by_name('input:0')
    logits = loaded_graph.get_tensor_by_name('predictions:0')
    target_sequence_length = loaded_graph.get_tensor_by_name('target_sequence_length:0')
    source_sequence_length = loaded_graph.get_tensor_by_name('source_sequence_length:0')
    keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')

    translate_logits = sess.run(logits, {input_data: [translate_sentence]*batch_size,
                                         target_sequence_length: [len(translate_sentence)*2]*batch_size,
                                         source_sequence_length: [len(translate_sentence)]*batch_size,
                                         keep_prob: 1.0})[0]

print('Input')
print('  Word Ids:      {}'.format([i for i in translate_sentence]))
print('  English Words: {}'.format([source_int_to_vocab[i] for i in translate_sentence]))

print('\nPrediction')
print('  Word Ids:      {}'.format([i for i in translate_logits]))
print('  French Words: {}'.format(" ".join([target_int_to_vocab[i] for i in translate_logits])))
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/dev
# Input
#   Word Ids:      [155, 52, 157, 152, 33, 203, 98]
#   English Words: ['he', 'saw', 'a', 'old', 'yellow', 'truck', '.']
#
# Prediction
#   Word Ids:      [244, 153, 103, 79, 124, 39, 287, 226, 1]
#   French Words: il a vu un vieux camion jaune . <EOS>

# %% [markdown]
# ## Imperfect Translation
# You might notice that some sentences translate better than others.  Since the dataset you're using only has a vocabulary of 227 English words of the thousands that you use, you're only going to see good results using these words.  For this project, you don't need a perfect translation. However, if you want to create a better translation model, you'll need better data.
#
# You can train on the [WMT10 French-English corpus](http://www.statmt.org/wmt10/training-giga-fren.tar).  This dataset has more vocabulary and richer in topics discussed.  However, this will take you days to train, so make sure you've a GPU and the neural network is performing well on dataset we provided.  Just make sure you play with the WMT10 corpus after you've submitted this project.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_language_translation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "helper.py" and "problem_unittests.py" files in your submission.
